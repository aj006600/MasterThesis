# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import KFold

import tensorflow as tf
# tf.random.set_seed(87)

import keras.backend as K
from keras.models import Model
from keras.layers import Input, BatchNormalization, GaussianNoise, Dense, Flatten
from keras.layers import Activation, Dropout, Concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam

import keras_tuner as kt
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

from livelossplot import PlotLossesKeras
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 一、資料前處理

# %% [markdown]
# ### 二、建立資料集

# %% [markdown]
# 2.1. open, high, low, close, volume, financing, fi, ii, di, rp, capital, 5ma, 10ma, 20ma (看5天後答案)

# %%
def get_label_data(shift):
    """
    open_time: K 線開盤時間 (UNIX 時間格式)
    open: 開盤價格
    high: 最高價
    low: 最低價
    close: 收盤價格
    volume: 交易量
    close_time: K 線收盤時間 (UNIX 時間格式)
    quote_volume: 報價資產量
    count: 交易數量
    taker_buy_volume: 吃單方在此期間買入的基礎資產數量
    taker_buy_quote_volume: 吃單方在此期間買入的報價資產數量
    """
    ticker_df = pd.read_csv('BTC_Test.csv')
    ticker_df['timestamp'] = pd.to_datetime(ticker_df['timestamp'])
    ticker_df = ticker_df.drop(columns=['close_time']) # 這個column沒有用

    data = ticker_df.copy()

    ### n個K棒後的答案 ###
    shift = 4 # 設定
    data[f'close_{shift}'] = data['close'].shift(-shift)
    data['ans'] = data[f'close_{shift}'] - data['close']

    ### 將timestamp變成index ###
    data.set_index('timestamp', inplace=True) # 先讓兩邊的index一樣才能併資料
    ticker_df.set_index('timestamp', inplace=True)

    data = data.dropna() # 為了讓NaN不會變0要先dropna()
    data['ans'] = (data['ans'] >= 0).astype(int)
    data = data.drop(columns=[f'close_{shift}'])

    ticker_df['ans'] = data['ans'] # 併資料
    ticker_df = ticker_df.dropna()

    ### 還原index ###
    data = data.reset_index()
    ticker_df = ticker_df.reset_index()

    return data, ticker_df

# %%
data, ticker_df = get_label_data(shift=4)
data.tail()
# Out:
#               timestamp     open     high      low    close    volume
# 958 2024-03-05 06:00:00  67062.4  67165.0  66700.1  67058.1  4975.596  \
# 959 2024-03-05 06:15:00  67058.0  67435.0  67052.6  67419.2  4636.991
# 960 2024-03-05 06:30:00  67419.2  67565.3  67287.2  67370.1  3797.674
# 961 2024-03-05 06:45:00  67370.0  67566.7  67273.9  67368.4  3027.573
# 962 2024-03-05 07:00:00  67368.5  67438.5  67161.8  67263.0  2437.294
#
#      quote_volume  count  taker_buy_volume  taker_buy_quote_volume  ignore
# 958  3.331500e+08  61523          2412.848            1.615565e+08       0  \
# 959  3.119854e+08  67732          2694.750            1.813060e+08       0
# 960  2.561869e+08  61614          1798.001            1.212977e+08       0
# 961  2.041419e+08  46184          1381.318            9.315399e+07       0
# 962  1.639535e+08  40707          1170.930            7.877032e+07       0
#
#             ema_9        ema_12        ema_26        macd      signal
# 958  67353.263428  67353.263428  67584.987174 -231.723746  -69.699478  \
# 959  67363.407516  67363.407516  67572.706642 -209.299126  -97.619408
# 960  67364.437129  67364.437129  67557.698743 -193.261614 -116.747849
# 961  67365.046801  67365.046801  67543.676614 -178.629812 -129.124242
# 962  67349.347293  67349.347293  67522.885753 -173.538460 -138.007085
#
#         rsi_14  ans
# 958  42.771435    1
# 959  47.918953    0
# 960  47.296010    0
# 961  47.273095    0
# 962  45.791784    0

# %% [markdown]
# 2.2. 分拆X, y

# %%
def data_preprocess(data, window_size): # target在data裡面

    ### 將data標準化成0~1 ###
    scaled_data = data.copy()
    scaled_data = scaled_data.drop(columns=['timestamp']) # 把timestamp和Ticker拿掉
    columns_to_scale = list(scaled_data.columns)

    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    scaled_data[columns_to_scale] = scaler_X.fit_transform(scaled_data[columns_to_scale])
    scaled_data = scaled_data.drop(columns=['ans'])

    X = np.array(scaled_data)
    y = scaler_y.fit_transform(data['ans'].values.reshape(-1, 1))

    ### 加入window_size ###
    data_X, data_y = [], []
    for i in range(len(X)-window_size-1):
        a = X[i:(i+window_size), :]
        data_X.append(a)
        data_y.append(y[i+window_size])

    data_X, data_y = np.array(data_X), np.array(data_y)

    return data_X, data_y

# %%
X, y = data_preprocess(data=data, window_size=20)
X.shape
# Out:
# (942, 20, 16)

# %% [markdown]
# 2.2.5. Flatten (MLP限定)

# %%
def make_X_flatten(X):
    X_flatten = X.reshape((X.shape[0], X.shape[1] * X.shape[2]))

    return X_flatten

# %%
X_flatten = make_X_flatten(X)

# %% [markdown]
# 2.4. 分拆train, valid

# %%
### 製作 trainning 資料 ###
train_X, train_y = get_label_data(unique_ticker=unique_ticker,
                                       start_date='2021-02-24', end_date='2023-03-04', shift=10,
                                       window_size=20)

### 製作 Validation 資料 ###
valid_X, valid_y = get_label_data(unique_ticker=unique_ticker,
                                       start_date='2023-03-05', end_date='2023-03-07', shift=10,
                                       window_size=20)
# Out:
# 4938 is failed
# 6153 is failed
# 4130 is failed
# 6901 is failed
# 6526 is failed
# 6805 is failed
# 4938 is failed
# 6153 is failed
# 4130 is failed
# 6526 is failed
# 6805 is failed

# %% [markdown]
# ### 三、訓練AE-MLP

# %% [markdown]
# 3.1. 建構AE-MLP model

# %%
def create_ae_mlp(hp, num_columns, num_labels):
    
    ##########
    ##########
    units_1 = hp.Int(name="units_1", min_value=16, max_value=256, step=16)
    units_2 = hp.Int(name="units_2", min_value=16, max_value=256, step=16)
    units_3 = hp.Int(name="units_3", min_value=16, max_value=256, step=16)
    units_4 = hp.Int(name="units_4", min_value=16, max_value=256, step=16)
    units_5 = hp.Int(name="units_5", min_value=16, max_value=256, step=16)
    units_6 = hp.Int(name="units_6", min_value=16, max_value=256, step=16)

    hidden_units = [units_1, units_2,
                    units_3,
                    units_4, units_5, units_6]
    
    dropout_1 = hp.Choice("dropout_1", [0.0, 0.2, 0.5])
    dropout_2 = hp.Choice("dropout_2", [0.0, 0.2, 0.5])
    dropout_3 = hp.Choice("dropout_3", [0.0, 0.2, 0.5])
    dropout_4 = hp.Choice("dropout_4", [0.0, 0.2, 0.5])
    dropout_5 = hp.Choice("dropout_5", [0.0, 0.2, 0.5])
    dropout_6 = hp.Choice("dropout_6", [0.0, 0.2, 0.5])
    dropout_7 = hp.Choice("dropout_7", [0.0, 0.2, 0.5])
    dropout_8 = hp.Choice("dropout_8", [0.0, 0.2, 0.5])

    dropout_rates = [dropout_1, dropout_2, dropout_3, dropout_4,
                     dropout_5, dropout_6, dropout_7, dropout_8]
    
    ls = hp.Choice('ls',[1e-2, 1e-3, 1e-5])
    lr = hp.Choice('lr',[1e-2, 1e-3, 1e-5])
    ##########
    ##########

    inp = tf.keras.layers.Input(shape = (num_columns, ))
    x0 = tf.keras.layers.BatchNormalization()(inp)
    
    encoder = tf.keras.layers.GaussianNoise(dropout_rates[0])(x0)
    encoder = tf.keras.layers.Dense(hidden_units[0])(encoder)
    encoder = tf.keras.layers.BatchNormalization()(encoder)
    encoder = tf.keras.layers.Activation('swish')(encoder)
    
    decoder = tf.keras.layers.Dropout(dropout_rates[1])(encoder)
    decoder = tf.keras.layers.Dense(num_columns, name = 'decoder')(decoder)  

    x_ae = tf.keras.layers.Dense(hidden_units[1])(decoder)
    x_ae = tf.keras.layers.BatchNormalization()(x_ae)
    x_ae = tf.keras.layers.Activation('swish')(x_ae)
    x_ae = tf.keras.layers.Dropout(dropout_rates[2])(x_ae)

    out_ae = tf.keras.layers.Dense(num_labels, activation = 'sigmoid', name = 'ae_action')(x_ae)
    
    x = tf.keras.layers.Concatenate()([x0, encoder])
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout_rates[3])(x)
    
    for i in range(2, len(hidden_units)):
        x = tf.keras.layers.Dense(hidden_units[i])(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Activation('swish')(x)
        x = tf.keras.layers.Dropout(dropout_rates[i + 2])(x)
        
    out = tf.keras.layers.Dense(num_labels, activation = 'sigmoid', name = 'action')(x)
    
    model = tf.keras.models.Model(inputs = inp, outputs = [decoder, out_ae, out])
    model.compile(optimizer = tf.keras.optimizers.legacy.Adam(learning_rate = lr),
                  loss = {'decoder': tf.keras.losses.MeanSquaredError(), 
                          'ae_action': tf.keras.losses.BinaryCrossentropy(label_smoothing = ls),
                          'action': tf.keras.losses.BinaryCrossentropy(label_smoothing = ls), 
                         },
                  metrics = {'decoder': tf.keras.metrics.MeanAbsoluteError(name = 'MAE'), 
                             'ae_action': tf.keras.metrics.AUC(name = 'AUC'), 
                             'action': tf.keras.metrics.AUC(name = 'AUC'), 
                            }, 
                 )
    
    return model

# %% [markdown]
# 3.2. 訓練, 找AE-MLP參數

# %%
TUNNING = True

if TUNNING:
    model_fn = lambda hp: create_ae_mlp(hp, num_columns=train_X.shape[1], num_labels=1)
    tuner = kt.BayesianOptimization(
                                    model_fn,
                                    objective=kt.Objective("val_action_AUC", direction="max"),
                                    max_trials=1,
                                    executions_per_trial=1,
                                    directory="AE-MLP_kt_test",
                                    overwrite=True,
                                    seed=87
                                    )
    # tuner.search_space_summary()
    es = EarlyStopping(monitor = 'val_action_AUC', min_delta = 1e-4, patience = 10, mode = 'max', 
                   baseline = None, restore_best_weights = True, verbose = 0)
    
    tuner.search(train_X, [train_X, train_y, train_y], validation_split=0.2, epochs=100, 
                 batch_size = 4096, callbacks = [es], verbose = 1)
    AE_MLP_model = tuner.get_best_models()[0]
# Out:
# Trial 1 Complete [00h 02m 13s]
# val_action_AUC: 0.5888948440551758
#
# Best val_action_AUC So Far: 0.5888948440551758
# Total elapsed time: 00h 02m 13s

# %% [markdown]
# 3.3. 輸出最佳參數

# %%
best_hyperparameters = tuner.get_best_hyperparameters()[0]

print("Best Hyperparameters:")
print(best_hyperparameters.values)

# 0.588 # {'units_1': 48, 'units_2': 112, 'units_3': 32, 'units_4': 64, 'units_5': 32, 'units_6': 112, 'dropout_1': 0.5, 'dropout_2': 0.2, 'dropout_3': 0.5, 'dropout_4': 0.2, 'dropout_5': 0.0, 'dropout_6': 0.2, 'dropout_7': 0.2, 'dropout_8': 0.0, 'ls': 0.001, 'lr': 0.01}
# Out:
# Best Hyperparameters:
# {'units_1': 48, 'units_2': 112, 'units_3': 32, 'units_4': 64, 'units_5': 32, 'units_6': 112, 'dropout_1': 0.5, 'dropout_2': 0.2, 'dropout_3': 0.5, 'dropout_4': 0.2, 'dropout_5': 0.0, 'dropout_6': 0.2, 'dropout_7': 0.2, 'dropout_8': 0.0, 'ls': 0.001, 'lr': 0.01}

# %% [markdown]
# ### 四、評估訓練出來的model

# %% [markdown]
# 4.1. 測試model在所有股票上

# %%
def test_my_model_whole_data(valid_X, valid_y, model):

    predictions = model.predict(valid_X)
    pred_k = predictions[2]
    pred_k = (pred_k > 0.5).astype(int)

    result_df = pd.DataFrame(pred_k, columns=['Pred'])
    result_df['True'] = valid_y

    match_count = (result_df['Pred'] == result_df['True']).sum()
    correct = match_count / len(result_df)

    print(f'ACC: {correct}\n')

    return result_df

result_df = test_my_model_whole_data(valid_X=valid_X, valid_y=valid_y, model=AE_MLP_model)
# Out:
# 1517/1517 [==============================] - 9s 6ms/step
# ACC: 0.6094329514547103

# %% [markdown]
# 4.2. 測試model在單一股票上

# %%
def test_my_model_one_ticker(ticker, model):

    test_X, test_y = make_concat_data_v1(unique_ticker=[ticker], start_date='2023-07-01', end_date='2023-11-30', shift=10, window_size=20)

    predictions = model.predict(test_X)
    pred_k = predictions[2]
    pred_k = (pred_k > 0.5).astype(int)

    result_df = pd.DataFrame(pred_k, columns=['Pred'])
    result_df['True'] = test_y

    match_count = (result_df['Pred'] == result_df['True']).sum()
    correct = match_count / len(result_df)

    print(f'\n{ticker} ACC: {correct}\n')
    print(result_df.head(60))

    return result_df

result_df = test_my_model_one_ticker(ticker=2330, model=AE_MLP_model)
# Out:
# 2/2 [==============================] - 0s 168ms/step
#
# 2330 ACC: 0.6181818181818182
#
#     Pred  True
# 0      0   0.0
# 1      0   0.0
# 2      0   0.0
# 3      0   1.0
# 4      0   1.0
# 5      0   0.0
# 6      0   0.0
# 7      1   0.0
# 8      1   0.0
# 9      1   0.0
# 10     0   0.0
# 11     1   0.0
# 12     0   0.0
# 13     0   0.0
# 14     0   0.0
# 15     0   0.0
# 16     1   0.0
# 17     1   0.0
# 18     1   1.0
# 19     1   1.0
# 20     1   1.0
# 21     1   1.0
# 22     1   1.0
# 23     1   1.0
# 24     1   1.0
# 25     1   1.0
# 26     1   1.0
# 27     1   1.0
# 28     1   1.0
# 29     1   1.0
# 30     1   0.0
# 31     1   0.0
# 32     1   0.0
# 33     1   0.0
# 34     1   0.0
# 35     1   1.0
# 36     1   0.0
# 37     1   1.0
# 38     1   1.0
# 39     1   1.0
# 40     1   1.0
# 41     1   1.0
# 42     1   1.0
# 43     1   1.0
# 44     1   1.0
# 45     1   1.0
# 46     0   1.0
# 47     0   1.0
# 48     0   1.0
# 49     0   1.0
# 50     0   1.0
# 51     0   1.0
# 52     0   0.0
# 53     1   1.0
# 54     1   0.0

# %% [markdown]
# ### 五、利用找出的參數(model)進行CV, 完整訓練, 預測

# %% [markdown]
# 5.1. 我的model

# %%
def create_ae_mlp(num_columns, num_labels, hidden_units, dropout_rates, ls, lr):
    
    tf.random.set_seed(87)
    
    inp = Input(shape = (num_columns, ))
    x0 = BatchNormalization()(inp)
    
    encoder = GaussianNoise(dropout_rates[0])(x0)
    encoder = Dense(hidden_units[0])(encoder)
    encoder = BatchNormalization()(encoder)
    encoder = Activation('swish')(encoder)
    
    decoder = Dropout(dropout_rates[1])(encoder)
    decoder = Dense(num_columns, name='decoder')(decoder)

    x_ae = Dense(hidden_units[1])(decoder)
    x_ae = BatchNormalization()(x_ae)
    x_ae = Activation('swish')(x_ae)
    x_ae = Dropout(dropout_rates[2])(x_ae)

    out_ae = Dense(num_labels, activation = 'sigmoid', name='ae_action')(x_ae)
    
    x = Concatenate()([x0, encoder])
    x = BatchNormalization()(x)
    x = Dropout(dropout_rates[3])(x)

    for i in range(2, len(hidden_units)):
        x = Dense(hidden_units[i])(x)
        x = BatchNormalization()(x)
        x = Activation('swish')(x)
        x = Dropout(dropout_rates[i + 2])(x)
        
    out = Dense(num_labels, activation = 'sigmoid', name = 'action')(x)
    
    model = Model(inputs = inp, outputs = [decoder, out_ae, out])
    model.compile(optimizer = Adam(learning_rate = lr),
                  loss = {'decoder': tf.keras.losses.MeanSquaredError(), 
                          'ae_action': tf.keras.losses.BinaryCrossentropy(label_smoothing = ls),
                          'action': tf.keras.losses.BinaryCrossentropy(label_smoothing = ls), 
                         },
                  metrics = {'decoder': tf.keras.metrics.MeanAbsoluteError(name = 'MAE'), 
                             'ae_action': tf.keras.metrics.AUC(name = 'AUC'), 
                             'action': tf.keras.metrics.AUC(name = 'AUC'), 
                            }, 
                 )
    
    return model

params = {'num_columns': train_X.shape[1],
          'num_labels': 1,
          'hidden_units': [48, 112, 32, 64, 32, 112],
          'dropout_rates': [0.5, 0.2, 0.5, 0.2, 0.0, 0.2, 0.2, 0.0],
          'ls': 0.001, 'lr': 0.01}

# %% [markdown]
# 5.2. 利用找出的參數進行model的CV

# %%
def AE_MLP_CV(batch_size, X, y):

    # import gc
    
    scores = []
    kf = KFold(n_splits=5, shuffle=True, random_state=87)
    split_indices = kf.split(X)
    for fold, (tr, te) in enumerate(split_indices):

        AE_MLP_path = f'AE_MLP_{fold+1}.hdf5'
        model = create_ae_mlp(**params)
        ckp = ModelCheckpoint(AE_MLP_path, monitor = 'val_action_AUC', verbose = 0, 
                            save_best_only = True, save_weights_only = True, mode = 'max')
        es = EarlyStopping(monitor = 'val_action_AUC', min_delta = 1e-4, patience = 10, mode = 'max', 
                        baseline = None, restore_best_weights = True, verbose = 0)
        history = model.fit(X[tr], [X[tr], y[tr], y[tr]], validation_data = (X[te], [X[te], y[te], y[te]]), 
                            # sample_weight = sw[tr], 
                            epochs = 100, batch_size = batch_size, callbacks = [ckp, es], verbose = 1)
        
        hist = pd.DataFrame(history.history)
        score = hist['val_action_AUC'].max()
        print(f'Fold {fold+1} \tROC AUC:', score)
        scores.append(score)

        K.clear_session()
        del model
        
        # rubbish = gc.collect()

    print('Average ROC AUC:', np.mean(scores))

    return hist, scores

hist, scores = AE_MLP_CV(batch_size=4096, X=train_X, y=train_y)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 13s 107ms/step - loss: 1.4376 - decoder_loss: 0.0574 - ae_action_loss: 0.6968 - action_loss: 0.6833 - decoder_MAE: 0.1631 - ae_action_AUC: 0.5671 - action_AUC: 0.5793 - val_loss: 1.4278 - val_decoder_loss: 0.0192 - val_ae_action_loss: 0.7213 - val_action_loss: 0.6873 - val_decoder_MAE: 0.1089 - val_ae_action_AUC: 0.5881 - val_action_AUC: 0.5938
# Epoch 2/100
# 94/94 [==============================] - 6s 60ms/step - loss: 1.3644 - decoder_loss: 0.0105 - ae_action_loss: 0.6788 - action_loss: 0.6752 - decoder_MAE: 0.0735 - ae_action_AUC: 0.5886 - action_AUC: 0.5976 - val_loss: 1.3848 - val_decoder_loss: 0.0142 - val_ae_action_loss: 0.6836 - val_action_loss: 0.6871 - val_decoder_MAE: 0.0925 - val_ae_action_AUC: 0.5951 - val_action_AUC: 0.5899
# Epoch 3/100
# 94/94 [==============================] - 6s 63ms/step - loss: 1.3590 - decoder_loss: 0.0078 - ae_action_loss: 0.6776 - action_loss: 0.6737 - decoder_MAE: 0.0623 - ae_action_AUC: 0.5919 - action_AUC: 0.6027 - val_loss: 1.3676 - val_decoder_loss: 0.0093 - val_ae_action_loss: 0.6785 - val_action_loss: 0.6799 - val_decoder_MAE: 0.0726 - val_ae_action_AUC: 0.5957 - val_action_AUC: 0.5972
# Epoch 4/100
# 94/94 [==============================] - 5s 56ms/step - loss: 1.3552 - decoder_loss: 0.0069 - ae_action_loss: 0.6762 - action_loss: 0.6720 - decoder_MAE: 0.0583 - ae_action_AUC: 0.5949 - action_AUC: 0.6064 - val_loss: 1.3562 - val_decoder_loss: 0.0063 - val_ae_action_loss: 0.6748 - val_action_loss: 0.6752 - val_decoder_MAE: 0.0562 - val_ae_action_AUC: 0.6018 - val_action_AUC: 0.6096
# Epoch 5/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3524 - decoder_loss: 0.0064 - ae_action_loss: 0.6754 - action_loss: 0.6706 - decoder_MAE: 0.0558 - ae_action_AUC: 0.5966 - action_AUC: 0.6093 - val_loss: 1.3503 - val_decoder_loss: 0.0050 - val_ae_action_loss: 0.6744 - val_action_loss: 0.6708 - val_decoder_MAE: 0.0472 - val_ae_action_AUC: 0.6044 - val_action_AUC: 0.6126
# Epoch 6/100
# 94/94 [==============================] - 5s 56ms/step - loss: 1.3501 - decoder_loss: 0.0062 - ae_action_loss: 0.6742 - action_loss: 0.6696 - decoder_MAE: 0.0549 - ae_action_AUC: 0.5986 - action_AUC: 0.6113 - val_loss: 1.3504 - val_decoder_loss: 0.0045 - val_ae_action_loss: 0.6783 - val_action_loss: 0.6676 - val_decoder_MAE: 0.0434 - val_ae_action_AUC: 0.6005 - val_action_AUC: 0.6166
# Epoch 7/100
# 94/94 [==============================] - 5s 56ms/step - loss: 1.3484 - decoder_loss: 0.0061 - ae_action_loss: 0.6737 - action_loss: 0.6686 - decoder_MAE: 0.0542 - ae_action_AUC: 0.5994 - action_AUC: 0.6132 - val_loss: 1.3417 - val_decoder_loss: 0.0044 - val_ae_action_loss: 0.6717 - val_action_loss: 0.6655 - val_decoder_MAE: 0.0419 - val_ae_action_AUC: 0.6068 - val_action_AUC: 0.6185
# Epoch 8/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3464 - decoder_loss: 0.0059 - ae_action_loss: 0.6728 - action_loss: 0.6677 - decoder_MAE: 0.0536 - ae_action_AUC: 0.6005 - action_AUC: 0.6146 - val_loss: 1.3418 - val_decoder_loss: 0.0043 - val_ae_action_loss: 0.6701 - val_action_loss: 0.6674 - val_decoder_MAE: 0.0416 - val_ae_action_AUC: 0.6075 - val_action_AUC: 0.6149
# Epoch 9/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3455 - decoder_loss: 0.0059 - ae_action_loss: 0.6724 - action_loss: 0.6671 - decoder_MAE: 0.0536 - ae_action_AUC: 0.6015 - action_AUC: 0.6162 - val_loss: 1.3438 - val_decoder_loss: 0.0045 - val_ae_action_loss: 0.6732 - val_action_loss: 0.6662 - val_decoder_MAE: 0.0433 - val_ae_action_AUC: 0.6076 - val_action_AUC: 0.6201
# Epoch 10/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3437 - decoder_loss: 0.0059 - ae_action_loss: 0.6715 - action_loss: 0.6664 - decoder_MAE: 0.0531 - ae_action_AUC: 0.6031 - action_AUC: 0.6174 - val_loss: 1.3353 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6678 - val_action_loss: 0.6634 - val_decoder_MAE: 0.0404 - val_ae_action_AUC: 0.6100 - val_action_AUC: 0.6228
# Epoch 11/100
# 94/94 [==============================] - 5s 56ms/step - loss: 1.3427 - decoder_loss: 0.0058 - ae_action_loss: 0.6714 - action_loss: 0.6655 - decoder_MAE: 0.0529 - ae_action_AUC: 0.6033 - action_AUC: 0.6192 - val_loss: 1.3378 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6702 - val_action_loss: 0.6635 - val_decoder_MAE: 0.0402 - val_ae_action_AUC: 0.6083 - val_action_AUC: 0.6231
# Epoch 12/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3412 - decoder_loss: 0.0058 - ae_action_loss: 0.6706 - action_loss: 0.6648 - decoder_MAE: 0.0528 - ae_action_AUC: 0.6045 - action_AUC: 0.6205 - val_loss: 1.3385 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6712 - val_action_loss: 0.6632 - val_decoder_MAE: 0.0405 - val_ae_action_AUC: 0.6104 - val_action_AUC: 0.6250
# Epoch 13/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3407 - decoder_loss: 0.0058 - ae_action_loss: 0.6706 - action_loss: 0.6643 - decoder_MAE: 0.0531 - ae_action_AUC: 0.6043 - action_AUC: 0.6213 - val_loss: 1.3336 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6672 - val_action_loss: 0.6624 - val_decoder_MAE: 0.0404 - val_ae_action_AUC: 0.6134 - val_action_AUC: 0.6260
# Epoch 14/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3405 - decoder_loss: 0.0058 - ae_action_loss: 0.6704 - action_loss: 0.6643 - decoder_MAE: 0.0529 - ae_action_AUC: 0.6060 - action_AUC: 0.6219 - val_loss: 1.3393 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6712 - val_action_loss: 0.6639 - val_decoder_MAE: 0.0405 - val_ae_action_AUC: 0.6101 - val_action_AUC: 0.6263
# Epoch 15/100
# 94/94 [==============================] - 6s 59ms/step - loss: 1.3393 - decoder_loss: 0.0058 - ae_action_loss: 0.6700 - action_loss: 0.6635 - decoder_MAE: 0.0527 - ae_action_AUC: 0.6054 - action_AUC: 0.6239 - val_loss: 1.3405 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6707 - val_action_loss: 0.6658 - val_decoder_MAE: 0.0398 - val_ae_action_AUC: 0.6108 - val_action_AUC: 0.6258
# Epoch 16/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3382 - decoder_loss: 0.0058 - ae_action_loss: 0.6695 - action_loss: 0.6629 - decoder_MAE: 0.0527 - ae_action_AUC: 0.6068 - action_AUC: 0.6245 - val_loss: 1.3305 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6654 - val_action_loss: 0.6612 - val_decoder_MAE: 0.0399 - val_ae_action_AUC: 0.6162 - val_action_AUC: 0.6288
# Epoch 17/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3374 - decoder_loss: 0.0057 - ae_action_loss: 0.6690 - action_loss: 0.6628 - decoder_MAE: 0.0521 - ae_action_AUC: 0.6079 - action_AUC: 0.6253 - val_loss: 1.3308 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6674 - val_action_loss: 0.6597 - val_decoder_MAE: 0.0379 - val_ae_action_AUC: 0.6143 - val_action_AUC: 0.6303
# Epoch 18/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3371 - decoder_loss: 0.0057 - ae_action_loss: 0.6692 - action_loss: 0.6622 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6073 - action_AUC: 0.6262 - val_loss: 1.3409 - val_decoder_loss: 0.0043 - val_ae_action_loss: 0.6719 - val_action_loss: 0.6647 - val_decoder_MAE: 0.0416 - val_ae_action_AUC: 0.6141 - val_action_AUC: 0.6282
# Epoch 19/100
# 94/94 [==============================] - 6s 59ms/step - loss: 1.3368 - decoder_loss: 0.0058 - ae_action_loss: 0.6691 - action_loss: 0.6619 - decoder_MAE: 0.0526 - ae_action_AUC: 0.6068 - action_AUC: 0.6271 - val_loss: 1.3423 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6778 - val_action_loss: 0.6605 - val_decoder_MAE: 0.0393 - val_ae_action_AUC: 0.6100 - val_action_AUC: 0.6314
# Epoch 20/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3353 - decoder_loss: 0.0057 - ae_action_loss: 0.6684 - action_loss: 0.6612 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6092 - action_AUC: 0.6295 - val_loss: 1.3300 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6664 - val_action_loss: 0.6598 - val_decoder_MAE: 0.0379 - val_ae_action_AUC: 0.6154 - val_action_AUC: 0.6328
# Epoch 21/100
# 94/94 [==============================] - 5s 57ms/step - loss: 1.3350 - decoder_loss: 0.0057 - ae_action_loss: 0.6685 - action_loss: 0.6607 - decoder_MAE: 0.0522 - ae_action_AUC: 0.6086 - action_AUC: 0.6296 - val_loss: 1.3290 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6667 - val_action_loss: 0.6584 - val_decoder_MAE: 0.0389 - val_ae_action_AUC: 0.6174 - val_action_AUC: 0.6329
# Epoch 22/100
# 94/94 [==============================] - 5s 58ms/step - loss: 1.3339 - decoder_loss: 0.0057 - ae_action_loss: 0.6680 - action_loss: 0.6603 - decoder_MAE: 0.0520 - ae_action_AUC: 0.6099 - action_AUC: 0.6307 - val_loss: 1.3284 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6644 - val_action_loss: 0.6603 - val_decoder_MAE: 0.0382 - val_ae_action_AUC: 0.6172 - val_action_AUC: 0.6331
# Epoch 23/100
# 94/94 [==============================] - 5s 56ms/step - loss: 1.3337 - decoder_loss: 0.0057 - ae_action_loss: 0.6681 - action_loss: 0.6599 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6099 - action_AUC: 0.6319 - val_loss: 1.3311 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6666 - val_action_loss: 0.6607 - val_decoder_MAE: 0.0383 - val_ae_action_AUC: 0.6146 - val_action_AUC: 0.6333
# Epoch 24/100
# 94/94 [==============================] - 5s 54ms/step - loss: 1.3330 - decoder_loss: 0.0057 - ae_action_loss: 0.6679 - action_loss: 0.6594 - decoder_MAE: 0.0520 - ae_action_AUC: 0.6099 - action_AUC: 0.6322 - val_loss: 1.3330 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6656 - val_action_loss: 0.6634 - val_decoder_MAE: 0.0398 - val_ae_action_AUC: 0.6166 - val_action_AUC: 0.6345
# Epoch 25/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3322 - decoder_loss: 0.0057 - ae_action_loss: 0.6675 - action_loss: 0.6590 - decoder_MAE: 0.0520 - ae_action_AUC: 0.6106 - action_AUC: 0.6335 - val_loss: 1.3275 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6663 - val_action_loss: 0.6575 - val_decoder_MAE: 0.0375 - val_ae_action_AUC: 0.6151 - val_action_AUC: 0.6377
# Epoch 26/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3322 - decoder_loss: 0.0058 - ae_action_loss: 0.6678 - action_loss: 0.6586 - decoder_MAE: 0.0524 - ae_action_AUC: 0.6105 - action_AUC: 0.6343 - val_loss: 1.3325 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6690 - val_action_loss: 0.6597 - val_decoder_MAE: 0.0377 - val_ae_action_AUC: 0.6137 - val_action_AUC: 0.6370
# Epoch 27/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3314 - decoder_loss: 0.0057 - ae_action_loss: 0.6676 - action_loss: 0.6581 - decoder_MAE: 0.0521 - ae_action_AUC: 0.6108 - action_AUC: 0.6353 - val_loss: 1.3288 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6669 - val_action_loss: 0.6581 - val_decoder_MAE: 0.0384 - val_ae_action_AUC: 0.6120 - val_action_AUC: 0.6367
# Epoch 28/100
# 94/94 [==============================] - 5s 54ms/step - loss: 1.3312 - decoder_loss: 0.0057 - ae_action_loss: 0.6674 - action_loss: 0.6580 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6116 - action_AUC: 0.6359 - val_loss: 1.3259 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6649 - val_action_loss: 0.6572 - val_decoder_MAE: 0.0376 - val_ae_action_AUC: 0.6147 - val_action_AUC: 0.6377
# Epoch 29/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3308 - decoder_loss: 0.0058 - ae_action_loss: 0.6676 - action_loss: 0.6573 - decoder_MAE: 0.0526 - ae_action_AUC: 0.6105 - action_AUC: 0.6370 - val_loss: 1.3253 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6644 - val_action_loss: 0.6571 - val_decoder_MAE: 0.0377 - val_ae_action_AUC: 0.6198 - val_action_AUC: 0.6394
# Epoch 30/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3303 - decoder_loss: 0.0058 - ae_action_loss: 0.6673 - action_loss: 0.6572 - decoder_MAE: 0.0521 - ae_action_AUC: 0.6105 - action_AUC: 0.6379 - val_loss: 1.3230 - val_decoder_loss: 0.0036 - val_ae_action_loss: 0.6646 - val_action_loss: 0.6549 - val_decoder_MAE: 0.0362 - val_ae_action_AUC: 0.6206 - val_action_AUC: 0.6421
# Epoch 31/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3294 - decoder_loss: 0.0058 - ae_action_loss: 0.6669 - action_loss: 0.6568 - decoder_MAE: 0.0524 - ae_action_AUC: 0.6125 - action_AUC: 0.6378 - val_loss: 1.3250 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6641 - val_action_loss: 0.6572 - val_decoder_MAE: 0.0371 - val_ae_action_AUC: 0.6201 - val_action_AUC: 0.6399
# Epoch 32/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3293 - decoder_loss: 0.0057 - ae_action_loss: 0.6670 - action_loss: 0.6566 - decoder_MAE: 0.0519 - ae_action_AUC: 0.6123 - action_AUC: 0.6392 - val_loss: 1.3249 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6636 - val_action_loss: 0.6575 - val_decoder_MAE: 0.0389 - val_ae_action_AUC: 0.6195 - val_action_AUC: 0.6390
# Epoch 33/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3287 - decoder_loss: 0.0058 - ae_action_loss: 0.6667 - action_loss: 0.6562 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6130 - action_AUC: 0.6396 - val_loss: 1.3225 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6635 - val_action_loss: 0.6552 - val_decoder_MAE: 0.0385 - val_ae_action_AUC: 0.6185 - val_action_AUC: 0.6420
# Epoch 34/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3283 - decoder_loss: 0.0058 - ae_action_loss: 0.6663 - action_loss: 0.6563 - decoder_MAE: 0.0520 - ae_action_AUC: 0.6131 - action_AUC: 0.6392 - val_loss: 1.3224 - val_decoder_loss: 0.0036 - val_ae_action_loss: 0.6641 - val_action_loss: 0.6547 - val_decoder_MAE: 0.0361 - val_ae_action_AUC: 0.6183 - val_action_AUC: 0.6430
# Epoch 35/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3272 - decoder_loss: 0.0057 - ae_action_loss: 0.6661 - action_loss: 0.6555 - decoder_MAE: 0.0519 - ae_action_AUC: 0.6148 - action_AUC: 0.6408 - val_loss: 1.3298 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6670 - val_action_loss: 0.6589 - val_decoder_MAE: 0.0389 - val_ae_action_AUC: 0.6182 - val_action_AUC: 0.6427
# Epoch 36/100
# 94/94 [==============================] - 5s 57ms/step - loss: 1.3274 - decoder_loss: 0.0058 - ae_action_loss: 0.6662 - action_loss: 0.6554 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6146 - action_AUC: 0.6415 - val_loss: 1.3257 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6665 - val_action_loss: 0.6553 - val_decoder_MAE: 0.0388 - val_ae_action_AUC: 0.6177 - val_action_AUC: 0.6443
# Epoch 37/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3267 - decoder_loss: 0.0058 - ae_action_loss: 0.6661 - action_loss: 0.6548 - decoder_MAE: 0.0522 - ae_action_AUC: 0.6147 - action_AUC: 0.6426 - val_loss: 1.3299 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6689 - val_action_loss: 0.6571 - val_decoder_MAE: 0.0379 - val_ae_action_AUC: 0.6215 - val_action_AUC: 0.6453
# Epoch 38/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3265 - decoder_loss: 0.0058 - ae_action_loss: 0.6658 - action_loss: 0.6549 - decoder_MAE: 0.0521 - ae_action_AUC: 0.6149 - action_AUC: 0.6421 - val_loss: 1.3199 - val_decoder_loss: 0.0036 - val_ae_action_loss: 0.6626 - val_action_loss: 0.6537 - val_decoder_MAE: 0.0361 - val_ae_action_AUC: 0.6225 - val_action_AUC: 0.6447
# Epoch 39/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3261 - decoder_loss: 0.0058 - ae_action_loss: 0.6659 - action_loss: 0.6544 - decoder_MAE: 0.0520 - ae_action_AUC: 0.6147 - action_AUC: 0.6435 - val_loss: 1.3265 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6672 - val_action_loss: 0.6552 - val_decoder_MAE: 0.0393 - val_ae_action_AUC: 0.6202 - val_action_AUC: 0.6454
# Epoch 40/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3260 - decoder_loss: 0.0058 - ae_action_loss: 0.6656 - action_loss: 0.6546 - decoder_MAE: 0.0521 - ae_action_AUC: 0.6152 - action_AUC: 0.6429 - val_loss: 1.3187 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6615 - val_action_loss: 0.6535 - val_decoder_MAE: 0.0370 - val_ae_action_AUC: 0.6247 - val_action_AUC: 0.6449
# Epoch 41/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3258 - decoder_loss: 0.0058 - ae_action_loss: 0.6655 - action_loss: 0.6545 - decoder_MAE: 0.0521 - ae_action_AUC: 0.6161 - action_AUC: 0.6431 - val_loss: 1.3216 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6638 - val_action_loss: 0.6541 - val_decoder_MAE: 0.0366 - val_ae_action_AUC: 0.6189 - val_action_AUC: 0.6455
# Epoch 42/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3256 - decoder_loss: 0.0058 - ae_action_loss: 0.6658 - action_loss: 0.6540 - decoder_MAE: 0.0521 - ae_action_AUC: 0.6148 - action_AUC: 0.6446 - val_loss: 1.3176 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6620 - val_action_loss: 0.6519 - val_decoder_MAE: 0.0382 - val_ae_action_AUC: 0.6241 - val_action_AUC: 0.6481
# Epoch 43/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3250 - decoder_loss: 0.0058 - ae_action_loss: 0.6654 - action_loss: 0.6538 - decoder_MAE: 0.0522 - ae_action_AUC: 0.6159 - action_AUC: 0.6450 - val_loss: 1.3349 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6730 - val_action_loss: 0.6578 - val_decoder_MAE: 0.0386 - val_ae_action_AUC: 0.6181 - val_action_AUC: 0.6454
# Epoch 44/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3247 - decoder_loss: 0.0059 - ae_action_loss: 0.6653 - action_loss: 0.6536 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6157 - action_AUC: 0.6454 - val_loss: 1.3214 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6630 - val_action_loss: 0.6545 - val_decoder_MAE: 0.0389 - val_ae_action_AUC: 0.6217 - val_action_AUC: 0.6452
# Epoch 45/100
# 94/94 [==============================] - 5s 54ms/step - loss: 1.3247 - decoder_loss: 0.0059 - ae_action_loss: 0.6654 - action_loss: 0.6534 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6161 - action_AUC: 0.6457 - val_loss: 1.3176 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6624 - val_action_loss: 0.6515 - val_decoder_MAE: 0.0361 - val_ae_action_AUC: 0.6237 - val_action_AUC: 0.6492
# Epoch 46/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3244 - decoder_loss: 0.0059 - ae_action_loss: 0.6657 - action_loss: 0.6529 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6152 - action_AUC: 0.6468 - val_loss: 1.3180 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6620 - val_action_loss: 0.6523 - val_decoder_MAE: 0.0366 - val_ae_action_AUC: 0.6221 - val_action_AUC: 0.6485
# Epoch 47/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3232 - decoder_loss: 0.0058 - ae_action_loss: 0.6650 - action_loss: 0.6524 - decoder_MAE: 0.0517 - ae_action_AUC: 0.6171 - action_AUC: 0.6472 - val_loss: 1.3180 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6621 - val_action_loss: 0.6523 - val_decoder_MAE: 0.0363 - val_ae_action_AUC: 0.6248 - val_action_AUC: 0.6496
# Epoch 48/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3234 - decoder_loss: 0.0059 - ae_action_loss: 0.6652 - action_loss: 0.6523 - decoder_MAE: 0.0522 - ae_action_AUC: 0.6165 - action_AUC: 0.6479 - val_loss: 1.3226 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6649 - val_action_loss: 0.6540 - val_decoder_MAE: 0.0360 - val_ae_action_AUC: 0.6234 - val_action_AUC: 0.6489
# Epoch 49/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3232 - decoder_loss: 0.0059 - ae_action_loss: 0.6652 - action_loss: 0.6521 - decoder_MAE: 0.0524 - ae_action_AUC: 0.6162 - action_AUC: 0.6480 - val_loss: 1.3165 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6615 - val_action_loss: 0.6513 - val_decoder_MAE: 0.0358 - val_ae_action_AUC: 0.6241 - val_action_AUC: 0.6495
# Epoch 50/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3236 - decoder_loss: 0.0059 - ae_action_loss: 0.6652 - action_loss: 0.6525 - decoder_MAE: 0.0525 - ae_action_AUC: 0.6158 - action_AUC: 0.6475 - val_loss: 1.3231 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6640 - val_action_loss: 0.6551 - val_decoder_MAE: 0.0380 - val_ae_action_AUC: 0.6204 - val_action_AUC: 0.6477
# Epoch 51/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3230 - decoder_loss: 0.0060 - ae_action_loss: 0.6650 - action_loss: 0.6520 - decoder_MAE: 0.0528 - ae_action_AUC: 0.6174 - action_AUC: 0.6479 - val_loss: 1.3281 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6683 - val_action_loss: 0.6560 - val_decoder_MAE: 0.0372 - val_ae_action_AUC: 0.6179 - val_action_AUC: 0.6472
# Epoch 52/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3219 - decoder_loss: 0.0059 - ae_action_loss: 0.6648 - action_loss: 0.6512 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6174 - action_AUC: 0.6497 - val_loss: 1.3202 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6633 - val_action_loss: 0.6532 - val_decoder_MAE: 0.0359 - val_ae_action_AUC: 0.6253 - val_action_AUC: 0.6511
# Epoch 53/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3220 - decoder_loss: 0.0060 - ae_action_loss: 0.6647 - action_loss: 0.6513 - decoder_MAE: 0.0524 - ae_action_AUC: 0.6173 - action_AUC: 0.6499 - val_loss: 1.3186 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6637 - val_action_loss: 0.6511 - val_decoder_MAE: 0.0361 - val_ae_action_AUC: 0.6247 - val_action_AUC: 0.6517
# Epoch 54/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3214 - decoder_loss: 0.0060 - ae_action_loss: 0.6645 - action_loss: 0.6509 - decoder_MAE: 0.0525 - ae_action_AUC: 0.6180 - action_AUC: 0.6504 - val_loss: 1.3147 - val_decoder_loss: 0.0036 - val_ae_action_loss: 0.6612 - val_action_loss: 0.6499 - val_decoder_MAE: 0.0365 - val_ae_action_AUC: 0.6263 - val_action_AUC: 0.6521
# Epoch 55/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3212 - decoder_loss: 0.0060 - ae_action_loss: 0.6645 - action_loss: 0.6508 - decoder_MAE: 0.0526 - ae_action_AUC: 0.6178 - action_AUC: 0.6508 - val_loss: 1.3176 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6635 - val_action_loss: 0.6503 - val_decoder_MAE: 0.0373 - val_ae_action_AUC: 0.6229 - val_action_AUC: 0.6530
# Epoch 56/100
# 94/94 [==============================] - 5s 57ms/step - loss: 1.3207 - decoder_loss: 0.0059 - ae_action_loss: 0.6641 - action_loss: 0.6507 - decoder_MAE: 0.0523 - ae_action_AUC: 0.6187 - action_AUC: 0.6505 - val_loss: 1.3177 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6634 - val_action_loss: 0.6506 - val_decoder_MAE: 0.0366 - val_ae_action_AUC: 0.6217 - val_action_AUC: 0.6515
# Epoch 57/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3210 - decoder_loss: 0.0060 - ae_action_loss: 0.6641 - action_loss: 0.6509 - decoder_MAE: 0.0524 - ae_action_AUC: 0.6191 - action_AUC: 0.6502 - val_loss: 1.3161 - val_decoder_loss: 0.0035 - val_ae_action_loss: 0.6617 - val_action_loss: 0.6508 - val_decoder_MAE: 0.0352 - val_ae_action_AUC: 0.6268 - val_action_AUC: 0.6523
# Epoch 58/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3208 - decoder_loss: 0.0060 - ae_action_loss: 0.6641 - action_loss: 0.6507 - decoder_MAE: 0.0526 - ae_action_AUC: 0.6186 - action_AUC: 0.6508 - val_loss: 1.3249 - val_decoder_loss: 0.0042 - val_ae_action_loss: 0.6672 - val_action_loss: 0.6535 - val_decoder_MAE: 0.0382 - val_ae_action_AUC: 0.6240 - val_action_AUC: 0.6507
# Epoch 59/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3206 - decoder_loss: 0.0060 - ae_action_loss: 0.6640 - action_loss: 0.6506 - decoder_MAE: 0.0527 - ae_action_AUC: 0.6183 - action_AUC: 0.6511 - val_loss: 1.3140 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6611 - val_action_loss: 0.6491 - val_decoder_MAE: 0.0374 - val_ae_action_AUC: 0.6260 - val_action_AUC: 0.6548
# Epoch 60/100
# 94/94 [==============================] - 5s 54ms/step - loss: 1.3198 - decoder_loss: 0.0060 - ae_action_loss: 0.6642 - action_loss: 0.6497 - decoder_MAE: 0.0524 - ae_action_AUC: 0.6190 - action_AUC: 0.6530 - val_loss: 1.3237 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6673 - val_action_loss: 0.6526 - val_decoder_MAE: 0.0364 - val_ae_action_AUC: 0.6257 - val_action_AUC: 0.6545
# Epoch 61/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3191 - decoder_loss: 0.0060 - ae_action_loss: 0.6636 - action_loss: 0.6495 - decoder_MAE: 0.0524 - ae_action_AUC: 0.6201 - action_AUC: 0.6533 - val_loss: 1.3156 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6622 - val_action_loss: 0.6498 - val_decoder_MAE: 0.0373 - val_ae_action_AUC: 0.6274 - val_action_AUC: 0.6539
# Epoch 62/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3190 - decoder_loss: 0.0061 - ae_action_loss: 0.6636 - action_loss: 0.6494 - decoder_MAE: 0.0529 - ae_action_AUC: 0.6202 - action_AUC: 0.6535 - val_loss: 1.3144 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6612 - val_action_loss: 0.6492 - val_decoder_MAE: 0.0404 - val_ae_action_AUC: 0.6260 - val_action_AUC: 0.6556
# Epoch 63/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3191 - decoder_loss: 0.0061 - ae_action_loss: 0.6638 - action_loss: 0.6492 - decoder_MAE: 0.0529 - ae_action_AUC: 0.6193 - action_AUC: 0.6542 - val_loss: 1.3169 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6620 - val_action_loss: 0.6512 - val_decoder_MAE: 0.0365 - val_ae_action_AUC: 0.6292 - val_action_AUC: 0.6541
# Epoch 64/100
# 94/94 [==============================] - 5s 54ms/step - loss: 1.3186 - decoder_loss: 0.0060 - ae_action_loss: 0.6634 - action_loss: 0.6492 - decoder_MAE: 0.0526 - ae_action_AUC: 0.6206 - action_AUC: 0.6535 - val_loss: 1.3134 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6616 - val_action_loss: 0.6481 - val_decoder_MAE: 0.0369 - val_ae_action_AUC: 0.6239 - val_action_AUC: 0.6557
# Epoch 65/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3185 - decoder_loss: 0.0061 - ae_action_loss: 0.6633 - action_loss: 0.6491 - decoder_MAE: 0.0528 - ae_action_AUC: 0.6208 - action_AUC: 0.6541 - val_loss: 1.3151 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6632 - val_action_loss: 0.6480 - val_decoder_MAE: 0.0371 - val_ae_action_AUC: 0.6198 - val_action_AUC: 0.6573
# Epoch 66/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3184 - decoder_loss: 0.0060 - ae_action_loss: 0.6636 - action_loss: 0.6488 - decoder_MAE: 0.0526 - ae_action_AUC: 0.6206 - action_AUC: 0.6548 - val_loss: 1.3164 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6621 - val_action_loss: 0.6504 - val_decoder_MAE: 0.0373 - val_ae_action_AUC: 0.6276 - val_action_AUC: 0.6567
# Epoch 67/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3183 - decoder_loss: 0.0061 - ae_action_loss: 0.6632 - action_loss: 0.6490 - decoder_MAE: 0.0526 - ae_action_AUC: 0.6208 - action_AUC: 0.6546 - val_loss: 1.3124 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6605 - val_action_loss: 0.6483 - val_decoder_MAE: 0.0358 - val_ae_action_AUC: 0.6283 - val_action_AUC: 0.6571
# Epoch 68/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3176 - decoder_loss: 0.0061 - ae_action_loss: 0.6630 - action_loss: 0.6485 - decoder_MAE: 0.0526 - ae_action_AUC: 0.6221 - action_AUC: 0.6555 - val_loss: 1.3138 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6613 - val_action_loss: 0.6487 - val_decoder_MAE: 0.0376 - val_ae_action_AUC: 0.6281 - val_action_AUC: 0.6580
# Epoch 69/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3173 - decoder_loss: 0.0060 - ae_action_loss: 0.6631 - action_loss: 0.6482 - decoder_MAE: 0.0524 - ae_action_AUC: 0.6217 - action_AUC: 0.6558 - val_loss: 1.3148 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6631 - val_action_loss: 0.6479 - val_decoder_MAE: 0.0365 - val_ae_action_AUC: 0.6213 - val_action_AUC: 0.6581
# Epoch 70/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3172 - decoder_loss: 0.0061 - ae_action_loss: 0.6629 - action_loss: 0.6482 - decoder_MAE: 0.0527 - ae_action_AUC: 0.6220 - action_AUC: 0.6560 - val_loss: 1.3115 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6601 - val_action_loss: 0.6477 - val_decoder_MAE: 0.0360 - val_ae_action_AUC: 0.6303 - val_action_AUC: 0.6579
# Epoch 71/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3171 - decoder_loss: 0.0061 - ae_action_loss: 0.6628 - action_loss: 0.6482 - decoder_MAE: 0.0530 - ae_action_AUC: 0.6224 - action_AUC: 0.6559 - val_loss: 1.3125 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6611 - val_action_loss: 0.6475 - val_decoder_MAE: 0.0380 - val_ae_action_AUC: 0.6282 - val_action_AUC: 0.6580
# Epoch 72/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3168 - decoder_loss: 0.0061 - ae_action_loss: 0.6627 - action_loss: 0.6480 - decoder_MAE: 0.0530 - ae_action_AUC: 0.6225 - action_AUC: 0.6564 - val_loss: 1.3123 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6611 - val_action_loss: 0.6474 - val_decoder_MAE: 0.0372 - val_ae_action_AUC: 0.6282 - val_action_AUC: 0.6583
# Epoch 73/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3174 - decoder_loss: 0.0061 - ae_action_loss: 0.6631 - action_loss: 0.6482 - decoder_MAE: 0.0527 - ae_action_AUC: 0.6216 - action_AUC: 0.6558 - val_loss: 1.3106 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6600 - val_action_loss: 0.6467 - val_decoder_MAE: 0.0375 - val_ae_action_AUC: 0.6297 - val_action_AUC: 0.6596
# Epoch 74/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3161 - decoder_loss: 0.0061 - ae_action_loss: 0.6623 - action_loss: 0.6476 - decoder_MAE: 0.0528 - ae_action_AUC: 0.6231 - action_AUC: 0.6568 - val_loss: 1.3108 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6601 - val_action_loss: 0.6467 - val_decoder_MAE: 0.0399 - val_ae_action_AUC: 0.6320 - val_action_AUC: 0.6600
# Epoch 75/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3161 - decoder_loss: 0.0061 - ae_action_loss: 0.6625 - action_loss: 0.6475 - decoder_MAE: 0.0528 - ae_action_AUC: 0.6226 - action_AUC: 0.6573 - val_loss: 1.3130 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6608 - val_action_loss: 0.6485 - val_decoder_MAE: 0.0361 - val_ae_action_AUC: 0.6311 - val_action_AUC: 0.6598
# Epoch 76/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3165 - decoder_loss: 0.0062 - ae_action_loss: 0.6626 - action_loss: 0.6477 - decoder_MAE: 0.0532 - ae_action_AUC: 0.6232 - action_AUC: 0.6566 - val_loss: 1.3139 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6618 - val_action_loss: 0.6481 - val_decoder_MAE: 0.0373 - val_ae_action_AUC: 0.6300 - val_action_AUC: 0.6590
# Epoch 77/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3162 - decoder_loss: 0.0062 - ae_action_loss: 0.6628 - action_loss: 0.6473 - decoder_MAE: 0.0531 - ae_action_AUC: 0.6225 - action_AUC: 0.6576 - val_loss: 1.3098 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6594 - val_action_loss: 0.6465 - val_decoder_MAE: 0.0362 - val_ae_action_AUC: 0.6295 - val_action_AUC: 0.6604
# Epoch 78/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3154 - decoder_loss: 0.0062 - ae_action_loss: 0.6625 - action_loss: 0.6467 - decoder_MAE: 0.0529 - ae_action_AUC: 0.6228 - action_AUC: 0.6586 - val_loss: 1.3117 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6619 - val_action_loss: 0.6460 - val_decoder_MAE: 0.0374 - val_ae_action_AUC: 0.6309 - val_action_AUC: 0.6606
# Epoch 79/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3149 - decoder_loss: 0.0061 - ae_action_loss: 0.6621 - action_loss: 0.6466 - decoder_MAE: 0.0529 - ae_action_AUC: 0.6235 - action_AUC: 0.6587 - val_loss: 1.3091 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6590 - val_action_loss: 0.6463 - val_decoder_MAE: 0.0375 - val_ae_action_AUC: 0.6305 - val_action_AUC: 0.6599
# Epoch 80/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3148 - decoder_loss: 0.0062 - ae_action_loss: 0.6621 - action_loss: 0.6464 - decoder_MAE: 0.0533 - ae_action_AUC: 0.6240 - action_AUC: 0.6591 - val_loss: 1.3137 - val_decoder_loss: 0.0042 - val_ae_action_loss: 0.6623 - val_action_loss: 0.6472 - val_decoder_MAE: 0.0396 - val_ae_action_AUC: 0.6301 - val_action_AUC: 0.6611
# Epoch 81/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3149 - decoder_loss: 0.0062 - ae_action_loss: 0.6622 - action_loss: 0.6465 - decoder_MAE: 0.0533 - ae_action_AUC: 0.6239 - action_AUC: 0.6593 - val_loss: 1.3094 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6592 - val_action_loss: 0.6464 - val_decoder_MAE: 0.0370 - val_ae_action_AUC: 0.6314 - val_action_AUC: 0.6615
# Epoch 82/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3149 - decoder_loss: 0.0062 - ae_action_loss: 0.6622 - action_loss: 0.6466 - decoder_MAE: 0.0532 - ae_action_AUC: 0.6235 - action_AUC: 0.6592 - val_loss: 1.3107 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6602 - val_action_loss: 0.6467 - val_decoder_MAE: 0.0370 - val_ae_action_AUC: 0.6312 - val_action_AUC: 0.6614
# Epoch 83/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3142 - decoder_loss: 0.0062 - ae_action_loss: 0.6618 - action_loss: 0.6461 - decoder_MAE: 0.0533 - ae_action_AUC: 0.6241 - action_AUC: 0.6599 - val_loss: 1.3087 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6590 - val_action_loss: 0.6459 - val_decoder_MAE: 0.0358 - val_ae_action_AUC: 0.6324 - val_action_AUC: 0.6626
# Epoch 84/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3143 - decoder_loss: 0.0062 - ae_action_loss: 0.6619 - action_loss: 0.6463 - decoder_MAE: 0.0530 - ae_action_AUC: 0.6247 - action_AUC: 0.6600 - val_loss: 1.3288 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6741 - val_action_loss: 0.6507 - val_decoder_MAE: 0.0372 - val_ae_action_AUC: 0.6303 - val_action_AUC: 0.6614
# Epoch 85/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3150 - decoder_loss: 0.0062 - ae_action_loss: 0.6623 - action_loss: 0.6466 - decoder_MAE: 0.0531 - ae_action_AUC: 0.6239 - action_AUC: 0.6598 - val_loss: 1.3156 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6633 - val_action_loss: 0.6482 - val_decoder_MAE: 0.0381 - val_ae_action_AUC: 0.6267 - val_action_AUC: 0.6599
# Epoch 86/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3141 - decoder_loss: 0.0062 - ae_action_loss: 0.6621 - action_loss: 0.6457 - decoder_MAE: 0.0533 - ae_action_AUC: 0.6244 - action_AUC: 0.6611 - val_loss: 1.3104 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6606 - val_action_loss: 0.6457 - val_decoder_MAE: 0.0383 - val_ae_action_AUC: 0.6309 - val_action_AUC: 0.6634
# Epoch 87/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3143 - decoder_loss: 0.0063 - ae_action_loss: 0.6618 - action_loss: 0.6462 - decoder_MAE: 0.0533 - ae_action_AUC: 0.6250 - action_AUC: 0.6603 - val_loss: 1.3089 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6597 - val_action_loss: 0.6451 - val_decoder_MAE: 0.0393 - val_ae_action_AUC: 0.6334 - val_action_AUC: 0.6632
# Epoch 88/100
# 94/94 [==============================] - 5s 57ms/step - loss: 1.3139 - decoder_loss: 0.0062 - ae_action_loss: 0.6616 - action_loss: 0.6461 - decoder_MAE: 0.0529 - ae_action_AUC: 0.6253 - action_AUC: 0.6601 - val_loss: 1.3088 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6595 - val_action_loss: 0.6454 - val_decoder_MAE: 0.0391 - val_ae_action_AUC: 0.6344 - val_action_AUC: 0.6627
# Epoch 89/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3131 - decoder_loss: 0.0063 - ae_action_loss: 0.6615 - action_loss: 0.6453 - decoder_MAE: 0.0536 - ae_action_AUC: 0.6256 - action_AUC: 0.6616 - val_loss: 1.3114 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6604 - val_action_loss: 0.6471 - val_decoder_MAE: 0.0373 - val_ae_action_AUC: 0.6313 - val_action_AUC: 0.6632
# Epoch 90/100
# 94/94 [==============================] - 6s 60ms/step - loss: 1.3128 - decoder_loss: 0.0063 - ae_action_loss: 0.6613 - action_loss: 0.6452 - decoder_MAE: 0.0535 - ae_action_AUC: 0.6261 - action_AUC: 0.6618 - val_loss: 1.3086 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6599 - val_action_loss: 0.6448 - val_decoder_MAE: 0.0385 - val_ae_action_AUC: 0.6326 - val_action_AUC: 0.6642
# Epoch 91/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3130 - decoder_loss: 0.0063 - ae_action_loss: 0.6616 - action_loss: 0.6452 - decoder_MAE: 0.0538 - ae_action_AUC: 0.6249 - action_AUC: 0.6619 - val_loss: 1.3139 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6638 - val_action_loss: 0.6461 - val_decoder_MAE: 0.0376 - val_ae_action_AUC: 0.6274 - val_action_AUC: 0.6618
# Epoch 92/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3127 - decoder_loss: 0.0064 - ae_action_loss: 0.6612 - action_loss: 0.6451 - decoder_MAE: 0.0540 - ae_action_AUC: 0.6256 - action_AUC: 0.6622 - val_loss: 1.3109 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6610 - val_action_loss: 0.6460 - val_decoder_MAE: 0.0375 - val_ae_action_AUC: 0.6301 - val_action_AUC: 0.6627
# Epoch 93/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3129 - decoder_loss: 0.0064 - ae_action_loss: 0.6613 - action_loss: 0.6453 - decoder_MAE: 0.0540 - ae_action_AUC: 0.6262 - action_AUC: 0.6616 - val_loss: 1.3082 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6593 - val_action_loss: 0.6451 - val_decoder_MAE: 0.0360 - val_ae_action_AUC: 0.6316 - val_action_AUC: 0.6644
# Epoch 94/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3119 - decoder_loss: 0.0063 - ae_action_loss: 0.6611 - action_loss: 0.6446 - decoder_MAE: 0.0537 - ae_action_AUC: 0.6265 - action_AUC: 0.6629 - val_loss: 1.3067 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6584 - val_action_loss: 0.6443 - val_decoder_MAE: 0.0380 - val_ae_action_AUC: 0.6337 - val_action_AUC: 0.6650
# Epoch 95/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3121 - decoder_loss: 0.0064 - ae_action_loss: 0.6614 - action_loss: 0.6443 - decoder_MAE: 0.0540 - ae_action_AUC: 0.6254 - action_AUC: 0.6638 - val_loss: 1.3065 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6580 - val_action_loss: 0.6445 - val_decoder_MAE: 0.0389 - val_ae_action_AUC: 0.6339 - val_action_AUC: 0.6648
# Epoch 96/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3123 - decoder_loss: 0.0063 - ae_action_loss: 0.6611 - action_loss: 0.6449 - decoder_MAE: 0.0535 - ae_action_AUC: 0.6257 - action_AUC: 0.6624 - val_loss: 1.3059 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6589 - val_action_loss: 0.6432 - val_decoder_MAE: 0.0363 - val_ae_action_AUC: 0.6305 - val_action_AUC: 0.6673
# Epoch 97/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3123 - decoder_loss: 0.0063 - ae_action_loss: 0.6612 - action_loss: 0.6448 - decoder_MAE: 0.0538 - ae_action_AUC: 0.6258 - action_AUC: 0.6627 - val_loss: 1.3086 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6595 - val_action_loss: 0.6452 - val_decoder_MAE: 0.0381 - val_ae_action_AUC: 0.6325 - val_action_AUC: 0.6657
# Epoch 98/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3118 - decoder_loss: 0.0064 - ae_action_loss: 0.6610 - action_loss: 0.6444 - decoder_MAE: 0.0540 - ae_action_AUC: 0.6269 - action_AUC: 0.6633 - val_loss: 1.3096 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6602 - val_action_loss: 0.6454 - val_decoder_MAE: 0.0383 - val_ae_action_AUC: 0.6350 - val_action_AUC: 0.6650
# Epoch 99/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3121 - decoder_loss: 0.0064 - ae_action_loss: 0.6609 - action_loss: 0.6448 - decoder_MAE: 0.0540 - ae_action_AUC: 0.6270 - action_AUC: 0.6627 - val_loss: 1.3071 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6582 - val_action_loss: 0.6451 - val_decoder_MAE: 0.0366 - val_ae_action_AUC: 0.6369 - val_action_AUC: 0.6652
# Epoch 100/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3111 - decoder_loss: 0.0063 - ae_action_loss: 0.6607 - action_loss: 0.6440 - decoder_MAE: 0.0537 - ae_action_AUC: 0.6274 - action_AUC: 0.6644 - val_loss: 1.3086 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6606 - val_action_loss: 0.6441 - val_decoder_MAE: 0.0365 - val_ae_action_AUC: 0.6327 - val_action_AUC: 0.6652
# Fold 1 	ROC AUC: 0.6672587394714355
# Epoch 1/100
# 94/94 [==============================] - 15s 118ms/step - loss: 1.4352 - decoder_loss: 0.0553 - ae_action_loss: 0.6975 - action_loss: 0.6825 - decoder_MAE: 0.1601 - ae_action_AUC: 0.5695 - action_AUC: 0.5811 - val_loss: 1.3897 - val_decoder_loss: 0.0187 - val_ae_action_loss: 0.6880 - val_action_loss: 0.6830 - val_decoder_MAE: 0.1081 - val_ae_action_AUC: 0.5879 - val_action_AUC: 0.5912
# Epoch 2/100
# 94/94 [==============================] - 6s 58ms/step - loss: 1.3630 - decoder_loss: 0.0095 - ae_action_loss: 0.6783 - action_loss: 0.6751 - decoder_MAE: 0.0696 - ae_action_AUC: 0.5897 - action_AUC: 0.5979 - val_loss: 1.3851 - val_decoder_loss: 0.0133 - val_ae_action_loss: 0.6834 - val_action_loss: 0.6884 - val_decoder_MAE: 0.0901 - val_ae_action_AUC: 0.5933 - val_action_AUC: 0.5718
# Epoch 3/100
# 94/94 [==============================] - 6s 59ms/step - loss: 1.3575 - decoder_loss: 0.0071 - ae_action_loss: 0.6774 - action_loss: 0.6730 - decoder_MAE: 0.0593 - ae_action_AUC: 0.5921 - action_AUC: 0.6029 - val_loss: 1.3683 - val_decoder_loss: 0.0087 - val_ae_action_loss: 0.6801 - val_action_loss: 0.6796 - val_decoder_MAE: 0.0706 - val_ae_action_AUC: 0.5978 - val_action_AUC: 0.6007
# Epoch 4/100
# 94/94 [==============================] - 5s 56ms/step - loss: 1.3543 - decoder_loss: 0.0064 - ae_action_loss: 0.6762 - action_loss: 0.6718 - decoder_MAE: 0.0556 - ae_action_AUC: 0.5941 - action_AUC: 0.6055 - val_loss: 1.3611 - val_decoder_loss: 0.0057 - val_ae_action_loss: 0.6755 - val_action_loss: 0.6799 - val_decoder_MAE: 0.0530 - val_ae_action_AUC: 0.6010 - val_action_AUC: 0.5906
# Epoch 5/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3520 - decoder_loss: 0.0061 - ae_action_loss: 0.6754 - action_loss: 0.6705 - decoder_MAE: 0.0544 - ae_action_AUC: 0.5965 - action_AUC: 0.6080 - val_loss: 1.3487 - val_decoder_loss: 0.0045 - val_ae_action_loss: 0.6737 - val_action_loss: 0.6705 - val_decoder_MAE: 0.0448 - val_ae_action_AUC: 0.6037 - val_action_AUC: 0.6093
# Epoch 6/100
# 94/94 [==============================] - 6s 61ms/step - loss: 1.3496 - decoder_loss: 0.0059 - ae_action_loss: 0.6746 - action_loss: 0.6692 - decoder_MAE: 0.0532 - ae_action_AUC: 0.5973 - action_AUC: 0.6114 - val_loss: 1.3514 - val_decoder_loss: 0.0042 - val_ae_action_loss: 0.6766 - val_action_loss: 0.6707 - val_decoder_MAE: 0.0408 - val_ae_action_AUC: 0.6009 - val_action_AUC: 0.6119
# Epoch 7/100
# 94/94 [==============================] - 6s 61ms/step - loss: 1.3480 - decoder_loss: 0.0059 - ae_action_loss: 0.6737 - action_loss: 0.6684 - decoder_MAE: 0.0533 - ae_action_AUC: 0.5989 - action_AUC: 0.6130 - val_loss: 1.3456 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6726 - val_action_loss: 0.6688 - val_decoder_MAE: 0.0408 - val_ae_action_AUC: 0.6062 - val_action_AUC: 0.6123
# Epoch 8/100
# 94/94 [==============================] - 5s 57ms/step - loss: 1.3463 - decoder_loss: 0.0058 - ae_action_loss: 0.6728 - action_loss: 0.6677 - decoder_MAE: 0.0527 - ae_action_AUC: 0.6006 - action_AUC: 0.6146 - val_loss: 1.3400 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6700 - val_action_loss: 0.6659 - val_decoder_MAE: 0.0401 - val_ae_action_AUC: 0.6053 - val_action_AUC: 0.6178
# Epoch 9/100
# 94/94 [==============================] - 5s 56ms/step - loss: 1.3447 - decoder_loss: 0.0057 - ae_action_loss: 0.6722 - action_loss: 0.6667 - decoder_MAE: 0.0527 - ae_action_AUC: 0.6019 - action_AUC: 0.6163 - val_loss: 1.3466 - val_decoder_loss: 0.0043 - val_ae_action_loss: 0.6757 - val_action_loss: 0.6665 - val_decoder_MAE: 0.0419 - val_ae_action_AUC: 0.6036 - val_action_AUC: 0.6174
# Epoch 10/100
# 94/94 [==============================] - 5s 54ms/step - loss: 1.3439 - decoder_loss: 0.0057 - ae_action_loss: 0.6720 - action_loss: 0.6662 - decoder_MAE: 0.0525 - ae_action_AUC: 0.6018 - action_AUC: 0.6175 - val_loss: 1.3410 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6722 - val_action_loss: 0.6647 - val_decoder_MAE: 0.0402 - val_ae_action_AUC: 0.6058 - val_action_AUC: 0.6208
# Epoch 11/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3426 - decoder_loss: 0.0057 - ae_action_loss: 0.6714 - action_loss: 0.6655 - decoder_MAE: 0.0522 - ae_action_AUC: 0.6028 - action_AUC: 0.6190 - val_loss: 1.3363 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6677 - val_action_loss: 0.6646 - val_decoder_MAE: 0.0396 - val_ae_action_AUC: 0.6097 - val_action_AUC: 0.6205
# Epoch 12/100
# 94/94 [==============================] - 6s 62ms/step - loss: 1.3418 - decoder_loss: 0.0057 - ae_action_loss: 0.6713 - action_loss: 0.6649 - decoder_MAE: 0.0524 - ae_action_AUC: 0.6027 - action_AUC: 0.6197 - val_loss: 1.3446 - val_decoder_loss: 0.0045 - val_ae_action_loss: 0.6724 - val_action_loss: 0.6678 - val_decoder_MAE: 0.0433 - val_ae_action_AUC: 0.6091 - val_action_AUC: 0.6221
# Epoch 13/100
# 94/94 [==============================] - 5s 54ms/step - loss: 1.3406 - decoder_loss: 0.0057 - ae_action_loss: 0.6706 - action_loss: 0.6643 - decoder_MAE: 0.0525 - ae_action_AUC: 0.6044 - action_AUC: 0.6217 - val_loss: 1.3332 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6667 - val_action_loss: 0.6627 - val_decoder_MAE: 0.0391 - val_ae_action_AUC: 0.6117 - val_action_AUC: 0.6239
# Epoch 14/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3402 - decoder_loss: 0.0057 - ae_action_loss: 0.6705 - action_loss: 0.6641 - decoder_MAE: 0.0522 - ae_action_AUC: 0.6044 - action_AUC: 0.6222 - val_loss: 1.3455 - val_decoder_loss: 0.0042 - val_ae_action_loss: 0.6751 - val_action_loss: 0.6662 - val_decoder_MAE: 0.0406 - val_ae_action_AUC: 0.6071 - val_action_AUC: 0.6242
# Epoch 15/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3388 - decoder_loss: 0.0056 - ae_action_loss: 0.6700 - action_loss: 0.6631 - decoder_MAE: 0.0521 - ae_action_AUC: 0.6051 - action_AUC: 0.6239 - val_loss: 1.3321 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6669 - val_action_loss: 0.6614 - val_decoder_MAE: 0.0382 - val_ae_action_AUC: 0.6120 - val_action_AUC: 0.6267
# Epoch 16/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3380 - decoder_loss: 0.0056 - ae_action_loss: 0.6695 - action_loss: 0.6629 - decoder_MAE: 0.0518 - ae_action_AUC: 0.6063 - action_AUC: 0.6250 - val_loss: 1.3373 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6680 - val_action_loss: 0.6654 - val_decoder_MAE: 0.0388 - val_ae_action_AUC: 0.6100 - val_action_AUC: 0.6246
# Epoch 17/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3374 - decoder_loss: 0.0056 - ae_action_loss: 0.6695 - action_loss: 0.6623 - decoder_MAE: 0.0516 - ae_action_AUC: 0.6060 - action_AUC: 0.6258 - val_loss: 1.3310 - val_decoder_loss: 0.0036 - val_ae_action_loss: 0.6667 - val_action_loss: 0.6607 - val_decoder_MAE: 0.0372 - val_ae_action_AUC: 0.6116 - val_action_AUC: 0.6287
# Epoch 18/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3369 - decoder_loss: 0.0056 - ae_action_loss: 0.6696 - action_loss: 0.6617 - decoder_MAE: 0.0518 - ae_action_AUC: 0.6061 - action_AUC: 0.6273 - val_loss: 1.3350 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6668 - val_action_loss: 0.6644 - val_decoder_MAE: 0.0392 - val_ae_action_AUC: 0.6128 - val_action_AUC: 0.6281
# Epoch 19/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3357 - decoder_loss: 0.0056 - ae_action_loss: 0.6687 - action_loss: 0.6614 - decoder_MAE: 0.0516 - ae_action_AUC: 0.6082 - action_AUC: 0.6283 - val_loss: 1.3411 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6703 - val_action_loss: 0.6668 - val_decoder_MAE: 0.0387 - val_ae_action_AUC: 0.6120 - val_action_AUC: 0.6269
# Epoch 20/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3353 - decoder_loss: 0.0056 - ae_action_loss: 0.6687 - action_loss: 0.6610 - decoder_MAE: 0.0517 - ae_action_AUC: 0.6082 - action_AUC: 0.6288 - val_loss: 1.3293 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6658 - val_action_loss: 0.6598 - val_decoder_MAE: 0.0378 - val_ae_action_AUC: 0.6152 - val_action_AUC: 0.6318
# Epoch 21/100
# ...
# Epoch 62/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3201 - decoder_loss: 0.0059 - ae_action_loss: 0.6639 - action_loss: 0.6503 - decoder_MAE: 0.0527 - ae_action_AUC: 0.6198 - action_AUC: 0.6528 - val_loss: 1.3174 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6630 - val_action_loss: 0.6507 - val_decoder_MAE: 0.0370 - val_ae_action_AUC: 0.6255 - val_action_AUC: 0.6507
# Epoch 63/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3197 - decoder_loss: 0.0060 - ae_action_loss: 0.6639 - action_loss: 0.6498 - decoder_MAE: 0.0529 - ae_action_AUC: 0.6199 - action_AUC: 0.6532 - val_loss: 1.3144 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6613 - val_action_loss: 0.6493 - val_decoder_MAE: 0.0371 - val_ae_action_AUC: 0.6267 - val_action_AUC: 0.6532
# Epoch 64/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3196 - decoder_loss: 0.0060 - ae_action_loss: 0.6637 - action_loss: 0.6498 - decoder_MAE: 0.0530 - ae_action_AUC: 0.6200 - action_AUC: 0.6532 - val_loss: 1.3154 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6618 - val_action_loss: 0.6500 - val_decoder_MAE: 0.0367 - val_ae_action_AUC: 0.6272 - val_action_AUC: 0.6525
# Epoch 65/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3190 - decoder_loss: 0.0060 - ae_action_loss: 0.6635 - action_loss: 0.6495 - decoder_MAE: 0.0529 - ae_action_AUC: 0.6209 - action_AUC: 0.6539 - val_loss: 1.3172 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6625 - val_action_loss: 0.6508 - val_decoder_MAE: 0.0374 - val_ae_action_AUC: 0.6249 - val_action_AUC: 0.6516
# Epoch 66/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3194 - decoder_loss: 0.0060 - ae_action_loss: 0.6637 - action_loss: 0.6497 - decoder_MAE: 0.0529 - ae_action_AUC: 0.6199 - action_AUC: 0.6539 - val_loss: 1.3152 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6615 - val_action_loss: 0.6499 - val_decoder_MAE: 0.0368 - val_ae_action_AUC: 0.6263 - val_action_AUC: 0.6529
# Epoch 67/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3189 - decoder_loss: 0.0061 - ae_action_loss: 0.6634 - action_loss: 0.6495 - decoder_MAE: 0.0530 - ae_action_AUC: 0.6213 - action_AUC: 0.6543 - val_loss: 1.3150 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6614 - val_action_loss: 0.6499 - val_decoder_MAE: 0.0375 - val_ae_action_AUC: 0.6265 - val_action_AUC: 0.6531
# Epoch 68/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3189 - decoder_loss: 0.0061 - ae_action_loss: 0.6638 - action_loss: 0.6490 - decoder_MAE: 0.0532 - ae_action_AUC: 0.6210 - action_AUC: 0.6551 - val_loss: 1.3154 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6612 - val_action_loss: 0.6503 - val_decoder_MAE: 0.0379 - val_ae_action_AUC: 0.6259 - val_action_AUC: 0.6533
# Epoch 69/100
# 94/94 [==============================] - 5s 54ms/step - loss: 1.3178 - decoder_loss: 0.0061 - ae_action_loss: 0.6632 - action_loss: 0.6485 - decoder_MAE: 0.0531 - ae_action_AUC: 0.6217 - action_AUC: 0.6560 - val_loss: 1.3146 - val_decoder_loss: 0.0036 - val_ae_action_loss: 0.6615 - val_action_loss: 0.6494 - val_decoder_MAE: 0.0359 - val_ae_action_AUC: 0.6260 - val_action_AUC: 0.6542
# Epoch 70/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3180 - decoder_loss: 0.0060 - ae_action_loss: 0.6633 - action_loss: 0.6487 - decoder_MAE: 0.0530 - ae_action_AUC: 0.6215 - action_AUC: 0.6557 - val_loss: 1.3180 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6632 - val_action_loss: 0.6511 - val_decoder_MAE: 0.0371 - val_ae_action_AUC: 0.6267 - val_action_AUC: 0.6542
# Epoch 71/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3181 - decoder_loss: 0.0061 - ae_action_loss: 0.6631 - action_loss: 0.6489 - decoder_MAE: 0.0533 - ae_action_AUC: 0.6224 - action_AUC: 0.6551 - val_loss: 1.3155 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6609 - val_action_loss: 0.6505 - val_decoder_MAE: 0.0389 - val_ae_action_AUC: 0.6264 - val_action_AUC: 0.6543
# Epoch 72/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3169 - decoder_loss: 0.0061 - ae_action_loss: 0.6627 - action_loss: 0.6481 - decoder_MAE: 0.0532 - ae_action_AUC: 0.6225 - action_AUC: 0.6568 - val_loss: 1.3136 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6604 - val_action_loss: 0.6494 - val_decoder_MAE: 0.0375 - val_ae_action_AUC: 0.6280 - val_action_AUC: 0.6547
# Epoch 73/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3169 - decoder_loss: 0.0062 - ae_action_loss: 0.6627 - action_loss: 0.6480 - decoder_MAE: 0.0535 - ae_action_AUC: 0.6223 - action_AUC: 0.6572 - val_loss: 1.3181 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6636 - val_action_loss: 0.6507 - val_decoder_MAE: 0.0370 - val_ae_action_AUC: 0.6285 - val_action_AUC: 0.6548
# Epoch 74/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3168 - decoder_loss: 0.0062 - ae_action_loss: 0.6627 - action_loss: 0.6480 - decoder_MAE: 0.0535 - ae_action_AUC: 0.6231 - action_AUC: 0.6570 - val_loss: 1.3112 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6596 - val_action_loss: 0.6478 - val_decoder_MAE: 0.0369 - val_ae_action_AUC: 0.6307 - val_action_AUC: 0.6578
# Epoch 75/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3164 - decoder_loss: 0.0061 - ae_action_loss: 0.6627 - action_loss: 0.6475 - decoder_MAE: 0.0533 - ae_action_AUC: 0.6225 - action_AUC: 0.6580 - val_loss: 1.3181 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6637 - val_action_loss: 0.6504 - val_decoder_MAE: 0.0380 - val_ae_action_AUC: 0.6274 - val_action_AUC: 0.6559
# Epoch 76/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3164 - decoder_loss: 0.0062 - ae_action_loss: 0.6628 - action_loss: 0.6474 - decoder_MAE: 0.0533 - ae_action_AUC: 0.6227 - action_AUC: 0.6581 - val_loss: 1.3148 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6612 - val_action_loss: 0.6497 - val_decoder_MAE: 0.0370 - val_ae_action_AUC: 0.6289 - val_action_AUC: 0.6550
# Epoch 77/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3164 - decoder_loss: 0.0062 - ae_action_loss: 0.6626 - action_loss: 0.6476 - decoder_MAE: 0.0538 - ae_action_AUC: 0.6229 - action_AUC: 0.6580 - val_loss: 1.3162 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6632 - val_action_loss: 0.6489 - val_decoder_MAE: 0.0402 - val_ae_action_AUC: 0.6275 - val_action_AUC: 0.6564
# Epoch 78/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3154 - decoder_loss: 0.0062 - ae_action_loss: 0.6621 - action_loss: 0.6471 - decoder_MAE: 0.0535 - ae_action_AUC: 0.6244 - action_AUC: 0.6588 - val_loss: 1.3118 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6595 - val_action_loss: 0.6483 - val_decoder_MAE: 0.0384 - val_ae_action_AUC: 0.6297 - val_action_AUC: 0.6572
# Epoch 79/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3155 - decoder_loss: 0.0063 - ae_action_loss: 0.6622 - action_loss: 0.6470 - decoder_MAE: 0.0538 - ae_action_AUC: 0.6244 - action_AUC: 0.6590 - val_loss: 1.3092 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6584 - val_action_loss: 0.6470 - val_decoder_MAE: 0.0365 - val_ae_action_AUC: 0.6318 - val_action_AUC: 0.6589
# Epoch 80/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3154 - decoder_loss: 0.0062 - ae_action_loss: 0.6620 - action_loss: 0.6472 - decoder_MAE: 0.0533 - ae_action_AUC: 0.6244 - action_AUC: 0.6590 - val_loss: 1.3108 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6598 - val_action_loss: 0.6469 - val_decoder_MAE: 0.0385 - val_ae_action_AUC: 0.6296 - val_action_AUC: 0.6589
# Epoch 81/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3142 - decoder_loss: 0.0062 - ae_action_loss: 0.6617 - action_loss: 0.6464 - decoder_MAE: 0.0534 - ae_action_AUC: 0.6247 - action_AUC: 0.6601 - val_loss: 1.3106 - val_decoder_loss: 0.0037 - val_ae_action_loss: 0.6601 - val_action_loss: 0.6468 - val_decoder_MAE: 0.0362 - val_ae_action_AUC: 0.6307 - val_action_AUC: 0.6600
# Epoch 82/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3147 - decoder_loss: 0.0062 - ae_action_loss: 0.6620 - action_loss: 0.6465 - decoder_MAE: 0.0533 - ae_action_AUC: 0.6250 - action_AUC: 0.6604 - val_loss: 1.3145 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6605 - val_action_loss: 0.6502 - val_decoder_MAE: 0.0366 - val_ae_action_AUC: 0.6285 - val_action_AUC: 0.6565
# Epoch 83/100
# 94/94 [==============================] - 5s 55ms/step - loss: 1.3145 - decoder_loss: 0.0062 - ae_action_loss: 0.6617 - action_loss: 0.6466 - decoder_MAE: 0.0536 - ae_action_AUC: 0.6256 - action_AUC: 0.6598 - val_loss: 1.3168 - val_decoder_loss: 0.0042 - val_ae_action_loss: 0.6626 - val_action_loss: 0.6500 - val_decoder_MAE: 0.0395 - val_ae_action_AUC: 0.6285 - val_action_AUC: 0.6585
# Epoch 84/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3144 - decoder_loss: 0.0062 - ae_action_loss: 0.6618 - action_loss: 0.6464 - decoder_MAE: 0.0535 - ae_action_AUC: 0.6252 - action_AUC: 0.6607 - val_loss: 1.3102 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6596 - val_action_loss: 0.6468 - val_decoder_MAE: 0.0366 - val_ae_action_AUC: 0.6309 - val_action_AUC: 0.6597
# Epoch 85/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3143 - decoder_loss: 0.0063 - ae_action_loss: 0.6616 - action_loss: 0.6464 - decoder_MAE: 0.0538 - ae_action_AUC: 0.6262 - action_AUC: 0.6603 - val_loss: 1.3109 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6595 - val_action_loss: 0.6474 - val_decoder_MAE: 0.0393 - val_ae_action_AUC: 0.6306 - val_action_AUC: 0.6600
# Epoch 86/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3139 - decoder_loss: 0.0063 - ae_action_loss: 0.6613 - action_loss: 0.6464 - decoder_MAE: 0.0535 - ae_action_AUC: 0.6253 - action_AUC: 0.6601 - val_loss: 1.3113 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6600 - val_action_loss: 0.6473 - val_decoder_MAE: 0.0382 - val_ae_action_AUC: 0.6294 - val_action_AUC: 0.6589
# Epoch 87/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3135 - decoder_loss: 0.0062 - ae_action_loss: 0.6614 - action_loss: 0.6459 - decoder_MAE: 0.0535 - ae_action_AUC: 0.6260 - action_AUC: 0.6613 - val_loss: 1.3140 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6603 - val_action_loss: 0.6496 - val_decoder_MAE: 0.0387 - val_ae_action_AUC: 0.6310 - val_action_AUC: 0.6582
# Epoch 88/100
# 94/94 [==============================] - 6s 60ms/step - loss: 1.3131 - decoder_loss: 0.0062 - ae_action_loss: 0.6613 - action_loss: 0.6455 - decoder_MAE: 0.0536 - ae_action_AUC: 0.6265 - action_AUC: 0.6623 - val_loss: 1.3091 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6586 - val_action_loss: 0.6465 - val_decoder_MAE: 0.0378 - val_ae_action_AUC: 0.6335 - val_action_AUC: 0.6608
# Epoch 89/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3135 - decoder_loss: 0.0063 - ae_action_loss: 0.6615 - action_loss: 0.6457 - decoder_MAE: 0.0541 - ae_action_AUC: 0.6257 - action_AUC: 0.6615 - val_loss: 1.3090 - val_decoder_loss: 0.0038 - val_ae_action_loss: 0.6593 - val_action_loss: 0.6458 - val_decoder_MAE: 0.0372 - val_ae_action_AUC: 0.6351 - val_action_AUC: 0.6608
# Epoch 90/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3135 - decoder_loss: 0.0063 - ae_action_loss: 0.6614 - action_loss: 0.6458 - decoder_MAE: 0.0537 - ae_action_AUC: 0.6264 - action_AUC: 0.6618 - val_loss: 1.3131 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6626 - val_action_loss: 0.6466 - val_decoder_MAE: 0.0377 - val_ae_action_AUC: 0.6275 - val_action_AUC: 0.6608
# Epoch 91/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3130 - decoder_loss: 0.0063 - ae_action_loss: 0.6614 - action_loss: 0.6453 - decoder_MAE: 0.0536 - ae_action_AUC: 0.6260 - action_AUC: 0.6622 - val_loss: 1.3104 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6606 - val_action_loss: 0.6458 - val_decoder_MAE: 0.0377 - val_ae_action_AUC: 0.6316 - val_action_AUC: 0.6618
# Epoch 92/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3127 - decoder_loss: 0.0064 - ae_action_loss: 0.6613 - action_loss: 0.6451 - decoder_MAE: 0.0539 - ae_action_AUC: 0.6262 - action_AUC: 0.6626 - val_loss: 1.3107 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6612 - val_action_loss: 0.6455 - val_decoder_MAE: 0.0376 - val_ae_action_AUC: 0.6304 - val_action_AUC: 0.6622
# Epoch 93/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3131 - decoder_loss: 0.0064 - ae_action_loss: 0.6615 - action_loss: 0.6453 - decoder_MAE: 0.0543 - ae_action_AUC: 0.6266 - action_AUC: 0.6627 - val_loss: 1.3101 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6599 - val_action_loss: 0.6461 - val_decoder_MAE: 0.0382 - val_ae_action_AUC: 0.6305 - val_action_AUC: 0.6614
# Epoch 94/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3128 - decoder_loss: 0.0063 - ae_action_loss: 0.6611 - action_loss: 0.6454 - decoder_MAE: 0.0536 - ae_action_AUC: 0.6269 - action_AUC: 0.6624 - val_loss: 1.3079 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6585 - val_action_loss: 0.6455 - val_decoder_MAE: 0.0378 - val_ae_action_AUC: 0.6321 - val_action_AUC: 0.6623
# Epoch 95/100
# 94/94 [==============================] - 5s 51ms/step - loss: 1.3127 - decoder_loss: 0.0063 - ae_action_loss: 0.6614 - action_loss: 0.6450 - decoder_MAE: 0.0538 - ae_action_AUC: 0.6265 - action_AUC: 0.6634 - val_loss: 1.3120 - val_decoder_loss: 0.0042 - val_ae_action_loss: 0.6608 - val_action_loss: 0.6470 - val_decoder_MAE: 0.0399 - val_ae_action_AUC: 0.6318 - val_action_AUC: 0.6611
# Epoch 96/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3122 - decoder_loss: 0.0063 - ae_action_loss: 0.6610 - action_loss: 0.6449 - decoder_MAE: 0.0540 - ae_action_AUC: 0.6270 - action_AUC: 0.6634 - val_loss: 1.3073 - val_decoder_loss: 0.0039 - val_ae_action_loss: 0.6586 - val_action_loss: 0.6448 - val_decoder_MAE: 0.0371 - val_ae_action_AUC: 0.6356 - val_action_AUC: 0.6635
# Epoch 97/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3120 - decoder_loss: 0.0064 - ae_action_loss: 0.6608 - action_loss: 0.6448 - decoder_MAE: 0.0543 - ae_action_AUC: 0.6277 - action_AUC: 0.6637 - val_loss: 1.3075 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6587 - val_action_loss: 0.6448 - val_decoder_MAE: 0.0373 - val_ae_action_AUC: 0.6337 - val_action_AUC: 0.6646
# Epoch 98/100
# 94/94 [==============================] - 5s 58ms/step - loss: 1.3123 - decoder_loss: 0.0064 - ae_action_loss: 0.6613 - action_loss: 0.6446 - decoder_MAE: 0.0539 - ae_action_AUC: 0.6263 - action_AUC: 0.6642 - val_loss: 1.3086 - val_decoder_loss: 0.0040 - val_ae_action_loss: 0.6588 - val_action_loss: 0.6458 - val_decoder_MAE: 0.0382 - val_ae_action_AUC: 0.6345 - val_action_AUC: 0.6633
# Epoch 99/100
# 94/94 [==============================] - 5s 53ms/step - loss: 1.3118 - decoder_loss: 0.0064 - ae_action_loss: 0.6608 - action_loss: 0.6446 - decoder_MAE: 0.0540 - ae_action_AUC: 0.6275 - action_AUC: 0.6636 - val_loss: 1.3105 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6609 - val_action_loss: 0.6455 - val_decoder_MAE: 0.0389 - val_ae_action_AUC: 0.6340 - val_action_AUC: 0.6638
# Epoch 100/100
# 94/94 [==============================] - 5s 52ms/step - loss: 1.3125 - decoder_loss: 0.0065 - ae_action_loss: 0.6612 - action_loss: 0.6449 - decoder_MAE: 0.0545 - ae_action_AUC: 0.6271 - action_AUC: 0.6635 - val_loss: 1.3085 - val_decoder_loss: 0.0041 - val_ae_action_loss: 0.6597 - val_action_loss: 0.6447 - val_decoder_MAE: 0.0388 - val_ae_action_AUC: 0.6328 - val_action_AUC: 0.6640
# Fold 5 	ROC AUC: 0.6645591855049133
# Average ROC AUC: 0.6644374251365661

# %%
# ### 偷懶不CV ###
# def AE_MLP_noCV(batch_size, X, y):

#     AE_MLP_path = f'AE_MLP.hdf5'
#     model = create_ae_mlp(**params)
#     ckp = ModelCheckpoint(AE_MLP_path, monitor = 'val_action_AUC', verbose = 0, 
#                         save_best_only = True, save_weights_only = True, mode = 'max')
#     es = EarlyStopping(monitor = 'val_action_AUC', min_delta = 1e-4, patience = 10, mode = 'max', 
#                     baseline = None, restore_best_weights = True, verbose = 0)
#     history = model.fit(X, [X, y, y], validation_split=0.2, 
#                         # sample_weight = sw[tr], 
#                         epochs = 100, batch_size = batch_size, callbacks = [ckp, es], verbose = 1)

#     hist = pd.DataFrame(history.history)
#     score = hist['val_action_AUC'].max()
#     print(f'ROC AUC:', score)

#     return history, model

# history, model = AE_MLP_noCV(batch_size=4096, X=train_X, y=train_y)

# %% [markdown]
# 5.3. 取出CV最佳的model

# %%
model = create_ae_mlp(**params)  
best_model_path = 'AE_MLP_4.hdf5'  # 選CV中預測能力最好的權重
model.load_weights(best_model_path)

# %% [markdown]
# 5.4. 測試在所有股票上

# %%
def test_my_model_whole_data(valid_X, valid_y, model):

    predictions = model.predict(valid_X)
    pred_k = predictions[2]
    pred_k = (pred_k > 0.5).astype(int)

    result_df = pd.DataFrame(pred_k, columns=['Pred'])
    result_df['True'] = valid_y

    match_count = (result_df['Pred'] == result_df['True']).sum()
    correct = match_count / len(result_df)

    print(f'ACC: {correct}\n')

    return result_df

result_df = test_my_model_whole_data(valid_X=valid_X, valid_y=valid_y, model=model)
# Out:
# 1517/1517 [==============================] - 9s 6ms/step
# ACC: 0.6175100964312207

# %% [markdown]
# 5.5. 測試在單一股票上

# %%
def test_my_model_one_ticker(ticker, model):

    test_X, test_y = make_concat_data_v1(unique_ticker=[ticker], start_date='2023-07-01', end_date='2023-11-30', shift=10, window_size=20)

    predictions = model.predict(test_X)
    pred_k = predictions[2]
    pred_k = (pred_k > 0.5).astype(int)

    result_df = pd.DataFrame(pred_k, columns=['Pred'])
    result_df['True'] = test_y

    match_count = (result_df['Pred'] == result_df['True']).sum()
    correct = match_count / len(result_df)

    print(f'\n{ticker} ACC: {correct}\n')
    print(result_df.head(60))

    return result_df

result_df = test_my_model_one_ticker(ticker=2330, model=model)
# Out:
# 2/2 [==============================] - 0s 95ms/step
#
# 2330 ACC: 0.6909090909090909
#
#     Pred  True
# 0      1   0.0
# 1      1   0.0
# 2      1   0.0
# 3      1   1.0
# 4      0   1.0
# 5      0   0.0
# 6      0   0.0
# 7      0   0.0
# 8      0   0.0
# 9      0   0.0
# 10     0   0.0
# 11     1   0.0
# 12     1   0.0
# 13     0   0.0
# 14     0   0.0
# 15     0   0.0
# 16     1   0.0
# 17     0   0.0
# 18     1   1.0
# 19     1   1.0
# 20     1   1.0
# 21     1   1.0
# 22     1   1.0
# 23     1   1.0
# 24     1   1.0
# 25     1   1.0
# 26     1   1.0
# 27     1   1.0
# 28     1   1.0
# 29     1   1.0
# 30     1   0.0
# 31     1   0.0
# 32     1   0.0
# 33     1   0.0
# 34     1   0.0
# 35     1   1.0
# 36     1   0.0
# 37     1   1.0
# 38     1   1.0
# 39     1   1.0
# 40     1   1.0
# 41     1   1.0
# 42     1   1.0
# 43     1   1.0
# 44     1   1.0
# 45     1   1.0
# 46     0   1.0
# 47     0   1.0
# 48     1   1.0
# 49     1   1.0
# 50     1   1.0
# 51     1   1.0
# 52     1   0.0
# 53     1   1.0
# 54     1   0.0
