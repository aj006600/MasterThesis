# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler, StandardScaler

import tensorflow as tf
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Dropout, LSTM, Conv1D, Flatten, MaxPooling1D, Activation
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam

import keras_tuner as kt
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 一、載入資料

# %% [markdown]
# 1.1. 載入資料

# %%
data = pd.read_csv('/Users/yitsung/Desktop/MasterThesis/data/TaiwanStockData_Top100_EMA')
ticker_2330 = data[data['ticker']==2330].reset_index(drop=True)
ticker_2330 = ticker_2330.drop(columns=['ticker'])
ticker_2330.tail()
# Out:
#            Date   open   high    low  close   volume  financing      fi
# 704  2023-11-27  573.0  577.0  568.0  568.0  20322.0     -112.0 -2153.0  \
# 705  2023-11-28  565.0  576.0  565.0  575.0  26932.0      478.0  3323.0
# 706  2023-11-29  578.0  579.0  570.0  574.0  27787.0      357.0  -180.0
# 707  2023-11-30  576.0  577.0  570.0  577.0  54365.0      -32.0  4730.0
# 708  2023-12-01  573.0  579.0  573.0  579.0  28798.0     -260.0  7120.0
#
#         ii      di      rp  capital        EMA9       EMA12       EMA26
# 704   59.0   -56.0 -3554.0   4.1507  573.659169  571.840469  562.945683  \
# 705  -98.0   687.0  -416.0   5.1624  573.927335  572.326550  563.838595
# 706   55.0  -553.0 -2383.0   4.8624  573.941868  572.584004  564.591292
# 707  -68.0  -770.0  -155.0   7.5527  574.553494  573.263388  565.510455
# 708 -611.0 -1060.0  2874.0   5.4736  575.442796  574.145944  566.509681
#
#          MACD    Signal      RSI14
# 704  8.894786  9.086560  81.069290
# 705  8.487955  8.966839  76.500832
# 706  7.992712  8.772014  71.301362
# 707  7.752933  8.568197  68.146342
# 708  7.636263  8.381811  61.941017

# %% [markdown]
# 1.2.轉換成EMA+return data

# %%
# origi_data #
origi_data = ticker_2330.copy() # 用來之後還原答案的

# ticker_2330['open'] = ticker_2330['open'].diff()
# ticker_2330['high'] = ticker_2330['high'].diff()
# ticker_2330['low'] = ticker_2330['low'].diff()
# ticker_2330['close'] = ticker_2330['close'].diff()

# # EMA diff #
# ticker_2330['EMA9'] = ticker_2330['EMA9'].diff()
# ticker_2330['EMA12'] = ticker_2330['EMA12'].diff()
# ticker_2330['EMA26'] = ticker_2330['EMA26'].diff()

# ticker_2330.replace([float('inf'), -float('inf')], 0, inplace=True) # 不知道為何有些調整過後會變inf, 要拿掉(應該是連兩天的價格都相同)
# ticker_2330 = ticker_2330.dropna().reset_index(drop=True)

ticker_2330.tail()
# Out:
#            Date   open   high    low  close   volume  financing      fi
# 704  2023-11-27  573.0  577.0  568.0  568.0  20322.0     -112.0 -2153.0  \
# 705  2023-11-28  565.0  576.0  565.0  575.0  26932.0      478.0  3323.0
# 706  2023-11-29  578.0  579.0  570.0  574.0  27787.0      357.0  -180.0
# 707  2023-11-30  576.0  577.0  570.0  577.0  54365.0      -32.0  4730.0
# 708  2023-12-01  573.0  579.0  573.0  579.0  28798.0     -260.0  7120.0
#
#         ii      di      rp  capital        EMA9       EMA12       EMA26
# 704   59.0   -56.0 -3554.0   4.1507  573.659169  571.840469  562.945683  \
# 705  -98.0   687.0  -416.0   5.1624  573.927335  572.326550  563.838595
# 706   55.0  -553.0 -2383.0   4.8624  573.941868  572.584004  564.591292
# 707  -68.0  -770.0  -155.0   7.5527  574.553494  573.263388  565.510455
# 708 -611.0 -1060.0  2874.0   5.4736  575.442796  574.145944  566.509681
#
#          MACD    Signal      RSI14
# 704  8.894786  9.086560  81.069290
# 705  8.487955  8.966839  76.500832
# 706  7.992712  8.772014  71.301362
# 707  7.752933  8.568197  68.146342
# 708  7.636263  8.381811  61.941017

# %% [markdown]
# 1.3.切Library和Prediction

# %%
Library = ticker_2330[ticker_2330['Date'] <= '2023-06-30'] # windows=20, 最後預測到6/30
Prediction = ticker_2330[(ticker_2330['Date'] >= '2023-06-01')&(ticker_2330['Date'] <= '2023-10-31')] # windows=20, 從6/1預測7/3開始
Prediction.tail()
# Out:
#            Date   open   high    low  close   volume  financing       fi
# 681  2023-10-25  544.0  551.0  544.0  544.0  17137.0      -99.0  -2573.0  \
# 682  2023-10-26  530.0  535.0  530.0  531.0  31683.0      487.0 -10712.0
# 683  2023-10-27  534.0  536.0  532.0  533.0  17051.0       17.0  -5262.0
# 684  2023-10-30  531.0  534.0  528.0  532.0  23299.0      265.0 -11811.0
# 685  2023-10-31  535.0  535.0  527.0  529.0  28073.0      113.0  -9363.0
#
#           ii      di       rp  capital        EMA9       EMA12       EMA26
# 681    651.0  -142.0   1185.0   3.9095  544.649068  543.673118  541.716547  \
# 682 -35173.0 -1744.0 -10261.0   6.9033  541.919255  541.723408  540.922728
# 683   1478.0   -73.0  -1739.0   4.1968  540.135404  540.381345  540.335860
# 684    487.0   378.0  -5803.0   5.6532  538.508323  539.091907  539.718389
# 685    495.0  -358.0  -5392.0   5.4314  536.606658  537.539306  538.924434
#
#          MACD    Signal      RSI14
# 681  1.956572  0.734048  91.909547
# 682  0.800679  0.747374  85.178131
# 683  0.045485  0.606996  78.927028
# 684 -0.626481  0.360301  72.836426
# 685 -1.385128  0.011215  63.359478

# %% [markdown]
# ### 二、資料分拆

# %% [markdown]
# 2.1.MinMax

# %%
def make_data_minmax(Library, Prediction, target):

    # 將target放至最後面 #
    Library_target_col = Library.pop(f'{target}')
    Library[f'{target}'] = Library_target_col
    Prediction_target_col = Prediction.pop(f'{target}')
    Prediction[f'{target}'] = Prediction_target_col

    # MinMax #
    scaler_X = MinMaxScaler()
    feature_to_standardize = Library.columns.to_list()[1 : -1]
    Library[feature_to_standardize] = scaler_X.fit_transform(Library[feature_to_standardize])
    Prediction[feature_to_standardize] = scaler_X.fit_transform(Prediction[feature_to_standardize])

    scaler_y = MinMaxScaler()
    Lib_ans = Library.iloc[:, -1].values.reshape(-1, 1)
    Library.iloc[:, -1] = scaler_y.fit_transform(Lib_ans)
    Pred_ans = Prediction.iloc[:, -1].values.reshape(-1, 1)
    Prediction.iloc[:, -1] = scaler_y.fit_transform(Pred_ans)

    return Library, Prediction, scaler_y

# %%
### 切train和validation ###
train_Library = Library[: int((len(Library) * 0.8))]
valid_Library = Library[int((len(Library) * 0.8)): ]
train_Library, valid_Library, scaler_y = make_data_minmax(Library=train_Library, Prediction=valid_Library, target='close')

### 切完整data ###
Library, Prediction, scaler_y = make_data_minmax(Library=Library, Prediction=Prediction, target='close')

# %% [markdown]
# 2.2.製作data

# %%
def create_dataset(data, windows, Tp, target):

    data = data.drop(columns=['Date'])
    num_of_target_col = data.columns.to_list().index(f'{target}')

    X, y = [], []
    for i in range(len(data) - windows - (Tp - 1)): # 預測t+1:-0, 預測t+2:-1 ...
        X.append(data.iloc[i:(i + windows)])
        y.append(data.iloc[i + windows + (Tp - 1), num_of_target_col])  # 預測t+1:+0, 預測t+2:+1 ... # 後面那個是target的索引

    X, y = np.array(X), np.array(y)
        
    return X, y

# %%
train_X, train_y = create_dataset(data=train_Library, windows=20, Tp=1, target='close')
valid_X, valid_y = create_dataset(data=valid_Library, windows=20, Tp=1, target='close')
X, y = create_dataset(data=Library, windows=20, Tp=1, target='close')
pred_X, pred_y = create_dataset(data=Prediction, windows=20, Tp=1, target='close')

# %% [markdown]
# 2.2.5. Flatten (MLP only)

# %%
def make_X_flatten(X):
    X_flatten = X.reshape((X.shape[0], X.shape[1] * X.shape[2]))

    return X_flatten

# %%
# train_X = make_X_flatten(train_X)
# valid_X = make_X_flatten(valid_X)
# pred_X = make_X_flatten(pred_X)

# %% [markdown]
# ### 三、建模分析

# %% [markdown]
# 3.1. 建構CNN model

# %%
def create_cnn(hp, num_columns):

    ################## Parameters ######################
    units_1 = hp.Int(name="units_1", min_value=16, max_value=128, step=16)
    units_2 = hp.Int(name="units_2", min_value=16, max_value=128, step=16)
    dropout_1 = hp.Choice("dropout_1", [0.0, 0.2, 0.5, 0.8])
    dropout_2 = hp.Choice("dropout_2", [0.0, 0.2, 0.5, 0.8])
    lr = hp.Choice('lr',[1e-2, 1e-3, 1e-5])
    ####################################################

    inp = Input(shape = (num_columns[1], num_columns[2]))

    x = Conv1D(units_1, 5, padding='same', activation='relu')(inp)
    x = MaxPooling1D(2)(x)
    x = Dropout(dropout_1)(x)

    x = Flatten()(x)

    x = Dense(units_2)(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_2)(x)

    out = Dense(1)(x)

    model = tf.keras.models.Model(inputs=inp, outputs=out)

    model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=lr),
                  loss='mean_squared_error',
                  metrics='mean_squared_error')

    
    return model

# %%
TUNNING = True

if TUNNING:
    model_fn = lambda hp: create_cnn(hp, num_columns=train_X.shape)
    tuner = kt.BayesianOptimization(model_fn,
                                    objective='val_mean_squared_error',
                                    max_trials=1,
                                    executions_per_trial=1,
                                    directory="CNN_price_kt",
                                    overwrite=True,
                                    seed=87)
    
    es = EarlyStopping(monitor='val_mean_squared_error', min_delta=1e-4, patience=10,
                       baseline=None, restore_best_weights=True, verbose=0)
    
    tuner.search(train_X, train_y, validation_data=(valid_X, valid_y), epochs=100, 
                 batch_size=16, callbacks=[es], verbose=1)
    
    CNN_model = tuner.get_best_models()[0]
# Out:
# Trial 1 Complete [00h 00m 07s]
# val_mean_squared_error: 0.008185838349163532
#
# Best val_mean_squared_error So Far: 0.008185838349163532
# Total elapsed time: 00h 00m 07s

# %%
best_hyperparameters = tuner.get_best_hyperparameters()[0]

print("Best Hyperparameters:")
print(best_hyperparameters.values)
# Out:
# Best Hyperparameters:
# {'units_1': 32, 'units_2': 64, 'dropout_1': 0.0, 'dropout_2': 0.0, 'lr': 0.01}

# %% [markdown]
# 3.3.完整訓練mlp

# %%
def create_cnn(num_columns, hidden_units, dropout_rates, lr):

    inp = Input(shape=(num_columns[1], num_columns[2]))

    x = Conv1D(hidden_units[0], 5, padding='same', activation='relu')(inp)
    x = MaxPooling1D(2)(x)
    x = Dropout(dropout_rates[0])(x)

    x = Flatten()(x)

    x = Dense(hidden_units[1])(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rates[1])(x)

    out = Dense(1)(x)

    model = tf.keras.models.Model(inputs=inp, outputs=out)

    model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=lr),
                  loss='mean_squared_error',
                  metrics='mean_squared_error')

    
    return model

params = {'num_columns': train_X.shape,
          'hidden_units': [32, 64],
          'dropout_rates': [0.0, 0.0],
          'lr': 0.01}

# %%
def train_CNN(batch_size, X, y):

    CNN_path = f'CNN.hdf5'

    model = create_cnn(**params)
    ckp = ModelCheckpoint(CNN_path, monitor='val_mean_squared_error', verbose=0, 
                        save_best_only=True, save_weights_only=True)
    es = EarlyStopping(monitor='val_mean_squared_error', min_delta=1e-4, patience=10, 
                       baseline=None, restore_best_weights=True, verbose=0)
    history = model.fit(X, y, validation_data=(valid_X, valid_y),
                        # sample_weight = sw[tr], 
                        epochs=100, batch_size=batch_size, callbacks=[ckp, es], verbose=1)

    hist = pd.DataFrame(history.history)
    score = hist['val_mean_squared_error'].min()
    print(f'MSE:', score)

    return history, model

history, model = train_CNN(batch_size=16, X=train_X, y=train_y)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 1s 12ms/step - loss: 0.5910 - mean_squared_error: 0.5910 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
# Epoch 2/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 3/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 4/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 5/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 6/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 7/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 8/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 9/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0105 - val_mean_squared_error: 0.0105
# Epoch 10/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0124 - val_mean_squared_error: 0.0124
# Epoch 11/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 12/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 13/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 14/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 15/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 16/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 17/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 18/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0096 - val_mean_squared_error: 0.0096
# Epoch 19/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 20/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 21/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 22/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 23/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 24/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 25/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 26/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 27/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 28/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 29/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 30/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 31/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 32/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 33/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 34/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 35/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 36/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 37/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 38/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 39/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 40/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 41/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 42/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 43/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 44/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 45/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# MSE: 0.004204531200230122

# %%
def test_model(pred_X, model):

    ### 預測 ###
    y_pred = model.predict(pred_X)
    y_pred = y_pred.reshape(-1,1) # reshape成可以還原的格式
    y_pred = scaler_y.inverse_transform(y_pred)
    y_pred = pd.Series(y_pred.reshape(-1)) # 變成series格式化成相同index方便畫圖

    # 取得前一日資料
    yesterday = origi_data[(origi_data['Date']>='2023-06-30') & (origi_data['Date']<'2023-10-31')].reset_index(drop=True)
    # 取得今日資料
    Today = origi_data[(origi_data['Date']>='2023-07-01') & (origi_data['Date']<'2023-11-01')].reset_index(drop=True)
    # Date
    Date = origi_data[(origi_data['Date']>='2023-07-01') & (origi_data['Date']<'2023-11-01')].reset_index()

    # 製作還原預測資料
    CNN_result = pd.DataFrame(yesterday['close'])
    CNN_result = CNN_result.rename(columns={'close': 'Yesterday'})

    CNN_result['Predictions'] = y_pred # origin
    # CNN_result['Predictions'] = CNN_result['Yesterday'] + y_pred # diff

    CNN_result['Observations'] = Today['close']   
    CNN_result['Date'] = Date['Date']

    CNN = CNN_result[['Date', 'Observations', 'Predictions', 'Yesterday']]

    # 繪圖
    plt.figure(figsize=(16, 9))
    plt.plot(CNN['Date'], CNN[f'Observations'], linewidth=3, label='true')
    plt.plot(CNN['Date'], CNN[f'Predictions'], linewidth=3, label='pred')
    plt.plot(CNN['Date'], CNN[f'Yesterday'], linestyle='--', label='yesterday')

    plt.xlabel('Date')
    plt.xticks(rotation=90, ha='right')
    plt.ylabel('Price')
    plt.title(f'2330 EMA CNN: close')
    plt.legend()
    plt.show()

    return CNN

CNN = test_model(pred_X=pred_X, model=model)
CNN
# Out:
# 3/3 [==============================] - 0s 10ms/step
#           Date  Observations  Predictions  Yesterday
# 0   2023-07-03         579.0   567.764160      576.0
# 1   2023-07-04         585.0   571.159180      579.0
# 2   2023-07-05         582.0   573.920349      585.0
# 3   2023-07-06         565.0   575.071716      582.0
# 4   2023-07-07         565.0   571.414795      565.0
# ..         ...           ...          ...        ...
# 78  2023-10-25         544.0   544.076538      544.0
# 79  2023-10-26         531.0   543.808350      544.0
# 80  2023-10-27         533.0   540.406494      531.0
# 81  2023-10-30         532.0   538.071411      533.0
# 82  2023-10-31         529.0   534.330505      532.0
#
# [83 rows x 4 columns]
