# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler, StandardScaler

import tensorflow as tf
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Dropout, LSTM, Bidirectional
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam

import keras_tuner as kt
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 一、載入資料

# %% [markdown]
# 1.1. 載入資料

# %%
data = pd.read_csv('/Users/yitsung/Desktop/MasterThesis/data/TaiwanStockData_Top100_EMA')
ticker_2330 = data[data['ticker']==2330].reset_index(drop=True)
ticker_2330 = ticker_2330.drop(columns=['ticker'])
ticker_2330.tail()
# Out:
#            Date   open   high    low  close   volume  financing      fi
# 704  2023-11-27  573.0  577.0  568.0  568.0  20322.0     -112.0 -2153.0  \
# 705  2023-11-28  565.0  576.0  565.0  575.0  26932.0      478.0  3323.0
# 706  2023-11-29  578.0  579.0  570.0  574.0  27787.0      357.0  -180.0
# 707  2023-11-30  576.0  577.0  570.0  577.0  54365.0      -32.0  4730.0
# 708  2023-12-01  573.0  579.0  573.0  579.0  28798.0     -260.0  7120.0
#
#         ii      di      rp  capital        EMA9       EMA12       EMA26
# 704   59.0   -56.0 -3554.0   4.1507  573.659169  571.840469  562.945683  \
# 705  -98.0   687.0  -416.0   5.1624  573.927335  572.326550  563.838595
# 706   55.0  -553.0 -2383.0   4.8624  573.941868  572.584004  564.591292
# 707  -68.0  -770.0  -155.0   7.5527  574.553494  573.263388  565.510455
# 708 -611.0 -1060.0  2874.0   5.4736  575.442796  574.145944  566.509681
#
#          MACD    Signal      RSI14
# 704  8.894786  9.086560  81.069290
# 705  8.487955  8.966839  76.500832
# 706  7.992712  8.772014  71.301362
# 707  7.752933  8.568197  68.146342
# 708  7.636263  8.381811  61.941017

# %% [markdown]
# 1.2.轉換成EMA+return data

# %%
# origi_data #
origi_data = ticker_2330.copy() # 用來之後還原答案的

# ticker_2330['open'] = ticker_2330['open'].diff()
# ticker_2330['high'] = ticker_2330['high'].diff()
# ticker_2330['low'] = ticker_2330['low'].diff()
# ticker_2330['close'] = ticker_2330['close'].diff()

# # EMA diff #
# ticker_2330['EMA9'] = ticker_2330['EMA9'].diff()
# ticker_2330['EMA12'] = ticker_2330['EMA12'].diff()
# ticker_2330['EMA26'] = ticker_2330['EMA26'].diff()

# ticker_2330.replace([float('inf'), -float('inf')], 0, inplace=True) # 不知道為何有些調整過後會變inf, 要拿掉(應該是連兩天的價格都相同)
# ticker_2330 = ticker_2330.dropna().reset_index(drop=True)

ticker_2330.tail()
# Out:
#            Date   open   high    low  close   volume  financing      fi
# 704  2023-11-27  573.0  577.0  568.0  568.0  20322.0     -112.0 -2153.0  \
# 705  2023-11-28  565.0  576.0  565.0  575.0  26932.0      478.0  3323.0
# 706  2023-11-29  578.0  579.0  570.0  574.0  27787.0      357.0  -180.0
# 707  2023-11-30  576.0  577.0  570.0  577.0  54365.0      -32.0  4730.0
# 708  2023-12-01  573.0  579.0  573.0  579.0  28798.0     -260.0  7120.0
#
#         ii      di      rp  capital        EMA9       EMA12       EMA26
# 704   59.0   -56.0 -3554.0   4.1507  573.659169  571.840469  562.945683  \
# 705  -98.0   687.0  -416.0   5.1624  573.927335  572.326550  563.838595
# 706   55.0  -553.0 -2383.0   4.8624  573.941868  572.584004  564.591292
# 707  -68.0  -770.0  -155.0   7.5527  574.553494  573.263388  565.510455
# 708 -611.0 -1060.0  2874.0   5.4736  575.442796  574.145944  566.509681
#
#          MACD    Signal      RSI14
# 704  8.894786  9.086560  81.069290
# 705  8.487955  8.966839  76.500832
# 706  7.992712  8.772014  71.301362
# 707  7.752933  8.568197  68.146342
# 708  7.636263  8.381811  61.941017

# %% [markdown]
# 1.3.切Library和Prediction

# %%
Library = ticker_2330[ticker_2330['Date'] <= '2023-06-30'] # windows=20, 最後預測到6/30
Prediction = ticker_2330[(ticker_2330['Date'] >= '2023-06-01')&(ticker_2330['Date'] <= '2023-10-31')] # windows=20, 從6/1預測7/3開始
Prediction.tail()
# Out:
#            Date   open   high    low  close   volume  financing       fi
# 681  2023-10-25  544.0  551.0  544.0  544.0  17137.0      -99.0  -2573.0  \
# 682  2023-10-26  530.0  535.0  530.0  531.0  31683.0      487.0 -10712.0
# 683  2023-10-27  534.0  536.0  532.0  533.0  17051.0       17.0  -5262.0
# 684  2023-10-30  531.0  534.0  528.0  532.0  23299.0      265.0 -11811.0
# 685  2023-10-31  535.0  535.0  527.0  529.0  28073.0      113.0  -9363.0
#
#           ii      di       rp  capital        EMA9       EMA12       EMA26
# 681    651.0  -142.0   1185.0   3.9095  544.649068  543.673118  541.716547  \
# 682 -35173.0 -1744.0 -10261.0   6.9033  541.919255  541.723408  540.922728
# 683   1478.0   -73.0  -1739.0   4.1968  540.135404  540.381345  540.335860
# 684    487.0   378.0  -5803.0   5.6532  538.508323  539.091907  539.718389
# 685    495.0  -358.0  -5392.0   5.4314  536.606658  537.539306  538.924434
#
#          MACD    Signal      RSI14
# 681  1.956572  0.734048  91.909547
# 682  0.800679  0.747374  85.178131
# 683  0.045485  0.606996  78.927028
# 684 -0.626481  0.360301  72.836426
# 685 -1.385128  0.011215  63.359478

# %% [markdown]
# ### 二、資料分拆

# %% [markdown]
# 2.1.MinMax

# %%
def make_data_minmax(Library, Prediction, target):

    # 將target放至最後面 #
    Library_target_col = Library.pop(f'{target}')
    Library[f'{target}'] = Library_target_col
    Prediction_target_col = Prediction.pop(f'{target}')
    Prediction[f'{target}'] = Prediction_target_col

    # MinMax #
    scaler_X = MinMaxScaler()
    feature_to_standardize = Library.columns.to_list()[1 : -1]
    Library[feature_to_standardize] = scaler_X.fit_transform(Library[feature_to_standardize])
    Prediction[feature_to_standardize] = scaler_X.fit_transform(Prediction[feature_to_standardize])

    scaler_y = MinMaxScaler()
    Lib_ans = Library.iloc[:, -1].values.reshape(-1, 1)
    Library.iloc[:, -1] = scaler_y.fit_transform(Lib_ans)
    Pred_ans = Prediction.iloc[:, -1].values.reshape(-1, 1)
    Prediction.iloc[:, -1] = scaler_y.fit_transform(Pred_ans)

    return Library, Prediction, scaler_y

# %%
### 切train和validation ###
train_Library = Library[: int((len(Library) * 0.8))]
valid_Library = Library[int((len(Library) * 0.8)): ]
train_Library, valid_Library, scaler_y = make_data_minmax(Library=train_Library, Prediction=valid_Library, target='close')

### 切完整data ###
Library, Prediction, scaler_y = make_data_minmax(Library=Library, Prediction=Prediction, target='close')

# %% [markdown]
# 2.2.製作data

# %%
def create_dataset(data, windows, Tp, target):

    data = data.drop(columns=['Date'])
    num_of_target_col = data.columns.to_list().index(f'{target}')

    X, y = [], []
    for i in range(len(data) - windows - (Tp - 1)): # 預測t+1:-0, 預測t+2:-1 ...
        X.append(data.iloc[i:(i + windows)])
        y.append(data.iloc[i + windows + (Tp - 1), num_of_target_col])  # 預測t+1:+0, 預測t+2:+1 ... # 後面那個是target的索引

    X, y = np.array(X), np.array(y)
        
    return X, y

# %%
train_X, train_y = create_dataset(data=train_Library, windows=20, Tp=1, target='close')
valid_X, valid_y = create_dataset(data=valid_Library, windows=20, Tp=1, target='close')
X, y = create_dataset(data=Library, windows=20, Tp=1, target='close')
pred_X, pred_y = create_dataset(data=Prediction, windows=20, Tp=1, target='close')

# %% [markdown]
# 2.2.5. Flatten (MLP only)

# %%
def make_X_flatten(X):
    X_flatten = X.reshape((X.shape[0], X.shape[1] * X.shape[2]))

    return X_flatten

# %%
# train_X = make_X_flatten(train_X)
# valid_X = make_X_flatten(valid_X)
# pred_X = make_X_flatten(pred_X)

# %% [markdown]
# ### 三、建模分析

# %% [markdown]
# 3.1. 建構BiLSTM model

# %%
def create_bilstm(hp, num_columns):

    ################## Parameters ######################
    units_1 = hp.Int(name="units_1", min_value=16, max_value=128, step=16)
    units_2 = hp.Int(name="units_2", min_value=16, max_value=128, step=16)
    units_3 = hp.Int(name="units_3", min_value=16, max_value=128, step=16)
    dropout_1 = hp.Choice("dropout_1", [0.0, 0.2, 0.5, 0.8])
    dropout_2 = hp.Choice("dropout_2", [0.0, 0.2, 0.5, 0.8])
    dropout_3 = hp.Choice("dropout_3", [0.0, 0.2, 0.5, 0.8])    
    lr = hp.Choice('lr',[1e-2, 1e-3, 1e-5])
    ####################################################

    inp = Input(shape = (num_columns[1], num_columns[2]))

    bilstm = Bidirectional(LSTM(units_1, return_sequences=True))(inp)
    bilstm = Dropout(dropout_1)(bilstm)
    
    bilstm = Bidirectional(LSTM(units_2))(bilstm)
    bilstm = Dropout(dropout_2)(bilstm)

    x = Dense(units_3)(bilstm)
    x = Dropout(dropout_3)(x)

    out = Dense(1)(x)

    model = tf.keras.models.Model(inputs=inp, outputs=out)

    model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=lr),
                  loss='mean_squared_error',
                  metrics='mean_squared_error')

    
    return model

# %%
TUNNING = True

if TUNNING:
    model_fn = lambda hp: create_bilstm(hp, num_columns=train_X.shape)
    tuner = kt.BayesianOptimization(model_fn,
                                    objective='val_mean_squared_error',
                                    max_trials=1,
                                    executions_per_trial=1,
                                    directory="BiLSTM_price_kt",
                                    overwrite=True,
                                    seed=87)
    
    es = EarlyStopping(monitor='val_mean_squared_error', min_delta=1e-4, patience=10,
                       baseline=None, restore_best_weights=True, verbose=0)
    
    tuner.search(train_X, train_y, validation_data=(valid_X, valid_y), epochs=100, 
                 batch_size=16, callbacks=[es], verbose=1)
    
    BiLSTM_model = tuner.get_best_models()[0]
# Out:
# Trial 1 Complete [00h 01m 39s]
# val_mean_squared_error: 0.015624729916453362
#
# Best val_mean_squared_error So Far: 0.015624729916453362
# Total elapsed time: 00h 01m 39s

# %%
best_hyperparameters = tuner.get_best_hyperparameters()[0]

print("Best Hyperparameters:")
print(best_hyperparameters.values)
# Out:
# Best Hyperparameters:
# {'units_1': 32, 'units_2': 64, 'units_3': 16, 'dropout_1': 0.0, 'dropout_2': 0.0, 'dropout_3': 0.2, 'lr': 1e-05}

# %% [markdown]
# 3.3.完整訓練mlp

# %%
def create_bilstm(num_columns, hidden_units, dropout_rates, lr):

    inp = Input(shape = (num_columns[1], num_columns[2]))

    bilstm = Bidirectional(LSTM(hidden_units[0], return_sequences=True))(inp)
    bilstm = Dropout(dropout_rates[0])(bilstm)
    
    bilstm = Bidirectional(LSTM(hidden_units[1]))(bilstm)
    bilstm = Dropout(dropout_rates[1])(bilstm)

    x = Dense(hidden_units[2])(bilstm)
    x = Dropout(dropout_rates[2])(x)

    out = Dense(1)(x)

    model = tf.keras.models.Model(inputs=inp, outputs=out)

    model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=lr),
                  loss='mean_squared_error',
                  metrics='mean_squared_error')

    return model

params = {'num_columns': train_X.shape,
          'hidden_units': [32, 64, 16],
          'dropout_rates': [0.0, 0.0, 0.2],
          'lr': 1e-05}

# %%
def train_BiLSTM(batch_size, X, y):

    BiLSTM_path = f'BiLSTM.hdf5'

    model = create_bilstm(**params)
    ckp = ModelCheckpoint(BiLSTM_path, monitor='val_mean_squared_error', verbose=0, 
                          save_best_only=True, save_weights_only=True)
    es = EarlyStopping(monitor='val_mean_squared_error', min_delta=1e-4, patience=10, 
                       baseline=None, restore_best_weights=True, verbose=0)
    history = model.fit(X, y, validation_data=(valid_X, valid_y),
                        # sample_weight = sw[tr], 
                        epochs=100, batch_size=batch_size, callbacks=[ckp, es], verbose=1)

    hist = pd.DataFrame(history.history)
    score = hist['val_mean_squared_error'].min()
    print(f'MSE:', score)

    return history, model

history, model = train_BiLSTM(batch_size=16, X=train_X, y=train_y)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 4s 67ms/step - loss: 0.5204 - mean_squared_error: 0.5204 - val_loss: 0.3372 - val_mean_squared_error: 0.3372
# Epoch 2/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.3465 - mean_squared_error: 0.3465 - val_loss: 0.2373 - val_mean_squared_error: 0.2373
# Epoch 3/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.2184 - mean_squared_error: 0.2184 - val_loss: 0.1641 - val_mean_squared_error: 0.1641
# Epoch 4/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.1356 - mean_squared_error: 0.1356 - val_loss: 0.1139 - val_mean_squared_error: 0.1139
# Epoch 5/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0854 - mean_squared_error: 0.0854 - val_loss: 0.0806 - val_mean_squared_error: 0.0806
# Epoch 6/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0549 - mean_squared_error: 0.0549 - val_loss: 0.0606 - val_mean_squared_error: 0.0606
# Epoch 7/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0416 - mean_squared_error: 0.0416 - val_loss: 0.0492 - val_mean_squared_error: 0.0492
# Epoch 8/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0324 - mean_squared_error: 0.0324 - val_loss: 0.0430 - val_mean_squared_error: 0.0430
# Epoch 9/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0395 - val_mean_squared_error: 0.0395
# Epoch 10/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0272 - mean_squared_error: 0.0272 - val_loss: 0.0379 - val_mean_squared_error: 0.0379
# Epoch 11/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 12/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0366 - val_mean_squared_error: 0.0366
# Epoch 13/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0216 - mean_squared_error: 0.0216 - val_loss: 0.0360 - val_mean_squared_error: 0.0360
# Epoch 14/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0357 - val_mean_squared_error: 0.0357
# Epoch 15/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0351 - val_mean_squared_error: 0.0351
# Epoch 16/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0351 - val_mean_squared_error: 0.0351
# Epoch 17/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0350 - val_mean_squared_error: 0.0350
# Epoch 18/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0348 - val_mean_squared_error: 0.0348
# Epoch 19/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0345 - val_mean_squared_error: 0.0345
# Epoch 20/100
# 29/29 [==============================] - 1s 37ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0342 - val_mean_squared_error: 0.0342
# Epoch 21/100
# 29/29 [==============================] - 1s 40ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0339 - val_mean_squared_error: 0.0339
# Epoch 22/100
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0340 - val_mean_squared_error: 0.0340
# Epoch 23/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0339 - val_mean_squared_error: 0.0339
# Epoch 24/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0335 - val_mean_squared_error: 0.0335
# Epoch 25/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 26/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 27/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 28/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0320 - val_mean_squared_error: 0.0320
# Epoch 29/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0320 - val_mean_squared_error: 0.0320
# Epoch 30/100
# 29/29 [==============================] - 1s 38ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0315 - val_mean_squared_error: 0.0315
# Epoch 31/100
# 29/29 [==============================] - 1s 38ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0312 - val_mean_squared_error: 0.0312
# Epoch 32/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0308 - val_mean_squared_error: 0.0308
# Epoch 33/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0305 - val_mean_squared_error: 0.0305
# Epoch 34/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0300 - val_mean_squared_error: 0.0300
# Epoch 35/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0295 - val_mean_squared_error: 0.0295
# Epoch 36/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0294 - val_mean_squared_error: 0.0294
# Epoch 37/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Epoch 38/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0284 - val_mean_squared_error: 0.0284
# Epoch 39/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 40/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 41/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0274 - val_mean_squared_error: 0.0274
# Epoch 42/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 43/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 44/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 45/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 46/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 47/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 48/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# Epoch 49/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 50/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 51/100
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 52/100
# 29/29 [==============================] - 1s 40ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 53/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 54/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 55/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 56/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 57/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 58/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 59/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 60/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 61/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 62/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 63/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 64/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 65/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 66/100
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0194 - val_mean_squared_error: 0.0194
# Epoch 67/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 68/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 69/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 70/100
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 71/100
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 72/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 73/100
# 29/29 [==============================] - 1s 36ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 74/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 75/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 76/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 77/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 78/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 79/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 80/100
# 29/29 [==============================] - 1s 32ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 81/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 82/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 83/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 84/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 85/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 86/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 87/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 88/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 89/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 90/100
# 29/29 [==============================] - 1s 33ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 91/100
# 29/29 [==============================] - 1s 34ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 92/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 93/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 94/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 95/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 96/100
# 29/29 [==============================] - 1s 30ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 97/100
# 29/29 [==============================] - 1s 31ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0152 - val_mean_squared_error: 0.0152
# Epoch 98/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 99/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 100/100
# 29/29 [==============================] - 1s 29ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# MSE: 0.0152156762778759

# %%
def test_model(pred_X, model):

    ### 預測 ###
    y_pred = model.predict(pred_X)
    y_pred = y_pred.reshape(-1,1) # reshape成可以還原的格式
    y_pred = scaler_y.inverse_transform(y_pred)
    y_pred = pd.Series(y_pred.reshape(-1)) # 變成series格式化成相同index方便畫圖


    # 取得前一日資料
    yesterday = origi_data[(origi_data['Date']>='2023-06-30') & (origi_data['Date']<'2023-10-31')].reset_index(drop=True)
    # 取得今日資料
    Today = origi_data[(origi_data['Date']>='2023-07-01') & (origi_data['Date']<'2023-11-01')].reset_index(drop=True)
    # Date
    Date = origi_data[(origi_data['Date']>='2023-07-01') & (origi_data['Date']<'2023-11-01')].reset_index()

    # 製作還原預測資料
    BiLSTM_result = pd.DataFrame(yesterday['close'])
    BiLSTM_result = BiLSTM_result.rename(columns={'close': 'Yesterday'})

    BiLSTM_result['Predictions'] = y_pred # origin
    # BiLSTM_result['Predictions'] = BiLSTM_result['Yesterday'] + y_pred # diff

    BiLSTM_result['Observations'] = Today['close']   
    BiLSTM_result['Date'] = Date['Date']

    BiLSTM = BiLSTM_result[['Date', 'Observations', 'Predictions', 'Yesterday']]

    # 繪圖
    plt.figure(figsize=(16, 9))
    plt.plot(BiLSTM['Date'], BiLSTM[f'Observations'], linewidth=3, label='true')
    plt.plot(BiLSTM['Date'], BiLSTM[f'Predictions'], linewidth=3, label='pred')
    plt.plot(BiLSTM['Date'], BiLSTM[f'Yesterday'], linestyle='--', label='yesterday')

    plt.xlabel('Date')
    plt.xticks(rotation=90, ha='right')
    plt.ylabel('Price')
    plt.title(f'2330 EMA BiLSTM: close')
    plt.legend()
    plt.show()

    return BiLSTM

BiLSTM = test_model(pred_X=pred_X, model=model)
BiLSTM
# Out:
# 3/3 [==============================] - 1s 39ms/step
#           Date  Observations  Predictions  Yesterday
# 0   2023-07-03         579.0   568.544556      576.0
# 1   2023-07-04         585.0   568.742493      579.0
# 2   2023-07-05         582.0   570.132507      585.0
# 3   2023-07-06         565.0   570.917542      582.0
# 4   2023-07-07         565.0   570.025146      565.0
# ..         ...           ...          ...        ...
# 78  2023-10-25         544.0   541.015320      544.0
# 79  2023-10-26         531.0   541.749023      544.0
# 80  2023-10-27         533.0   541.892700      531.0
# 81  2023-10-30         532.0   541.094604      533.0
# 82  2023-10-31         529.0   539.782166      532.0
#
# [83 rows x 4 columns]
